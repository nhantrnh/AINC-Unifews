# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This code will mount your Google Drive to the `/content/drive` directory in your Colab environment. You will be prompted to authorize access to your Google Drive.

# %%
import os

os.chdir("/content/drive/MyDrive/MS-HCMUS")
# Move to the directory Unifews

# %%
# !pwd
# Out:
# /content/drive/MyDrive/MS-HCMUS

# %%
# %pip install eigency
# Out:
# Collecting eigency
#   Downloading eigency-3.4.0.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from eigency) (2.0.2)
# Downloading eigency-3.4.0.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 14.7 MB/s eta 0:00:00
# Installing collected packages: eigency
# Successfully installed eigency-3.4.0.7

# %%
# copy project ra local
# !cp -r /content/drive/MyDrive/MS-HCMUS/Project/Unifews /content/

# move vào đó
# %cd /content/Unifews/precompute

# compile lại
# !python setup.py build_ext --inplace
# Out:
# /content/Unifews/precompute
# In file included from /usr/local/lib/python3.12/dist-packages/numpy/_core/include/numpy/ndarraytypes.h:1909,
#                  from /usr/local/lib/python3.12/dist-packages/numpy/_core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.12/dist-packages/numpy/_core/include/numpy/arrayobject.h:5,
#                  from prop.cpp:1280:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# In file included from algprop.cpp:7,
#                  from prop.cpp:1287:
# algprop.h:30: warning: ignoring ‘#pragma warning ’ [-Wunknown-pragmas]
#    30 | #pragma warning(push, 0)
#       |
# In file included from algprop.cpp:7,
#                  from prop.cpp:1287:
# algprop.h:32: warning: ignoring ‘#pragma warning ’ [-Wunknown-pragmas]
#    32 | #pragma warning(pop)
#       |

# %%
# !pwd
# Out:
# /content/Unifews/precompute

# %%
# %cd /content/drive/MyDrive/MS-HCMUS/Project/Unifews
# Out:
# /content/drive/.shortcut-targets-by-id/1_5kJLcXJuln6Z3yserbXXe9tK4T6UFOZ/Project/Unifews

# %%
import sys
sys.path.append("/content/Unifews/precompute")

import prop

# %%
# %pip install ptflops dotmap torch_geometric powerlaw
# Out:
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl.metadata (9.4 kB)
# Collecting dotmap
#   Downloading dotmap-1.3.30-py3-none-any.whl.metadata (3.2 kB)
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 1.6 MB/s eta 0:00:00
# Collecting powerlaw
#   Downloading powerlaw-2.0.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from ptflops) (2.10.0+cpu)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.13.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from powerlaw) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from powerlaw) (3.10.0)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.12/dist-packages (from powerlaw) (1.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.6.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->powerlaw) (1.17.0)
# Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Downloading dotmap-1.3.30-py3-none-any.whl (11 kB)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.6 MB/s eta 0:00:00
# Downloading powerlaw-2.0.0-py3-none-any.whl (191 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.0/192.0 kB 10.1 MB/s eta 0:00:00
# Installing collected packages: dotmap, torch_geometric, ptflops, powerlaw
# Successfully installed dotmap-1.3.30 powerlaw-2.0.0 ptflops-0.7.5 torch_geometric-2.7.0

# %%
# !rm /content/drive/MyDrive/MS-HCMUS/Project/Unifews/precompute/prop*.so
# Out:
# rm: cannot remove '/content/drive/MyDrive/MS-HCMUS/Project/Unifews/precompute/prop*.so': No such file or directory

# %%
# !ls -lh /content/Unifews/precompute
# Out:
# total 3.3M
# -rw------- 1 root root  12K Mar 28 05:53  algprop.cpp
# -rw------- 1 root root 2.5K Mar 28 05:53  algprop.h
# drwx------ 4 root root 4.0K Mar 28 05:53  build
# -rw------- 1 root root 477K Mar 28 05:53 'prop (1).cpp'
# -rw------- 1 root root    0 Mar 28 05:53 'prop (2).cpp'
# -rw------- 1 root root 477K Mar 28 05:53  prop.cpp
# -rwxr-xr-x 1 root root 2.3M Mar 28 05:59  prop.cpython-312-x86_64-linux-gnu.so
# -rw------- 1 root root  629 Mar 28 05:53  prop.pxd
# -rw------- 1 root root  938 Mar 28 05:53  prop.pyx
# -rw------- 1 root root  497 Mar 28 05:53  setup.py

# %%
# %cd /content/Unifews
# Out:
# /content/Unifews

# %%
# Tìm tất cả các file cache tiềm năng trong toàn bộ thư mục Unifews
# !find /content/Unifews -name "*.pt"
# !find /content/Unifews -name "*.npy"
# !find /content/Unifews -name "*.npz"
# Out:
# /content/Unifews/data/raw/Amazon/Computers/processed/data.pt
# /content/Unifews/data/raw/Amazon/Computers/processed/pre_filter.pt
# /content/Unifews/data/raw/Amazon/Computers/processed/pre_transform.pt
# /content/Unifews/data/raw/Coauthor/CS/processed/data.pt
# /content/Unifews/data/raw/Coauthor/CS/processed/pre_filter.pt
# /content/Unifews/data/raw/Coauthor/CS/processed/pre_transform.pt
# /content/Unifews/data/processed/raw/Amazon/Computers/processed/data.pt
# /content/Unifews/data/processed/raw/Amazon/Computers/processed/pre_filter.pt
# /content/Unifews/data/processed/raw/Amazon/Computers/processed/pre_transform.pt
# /content/Unifews/data/cora/feats.npy
# /content/Unifews/data/computers/feats.npy
# /content/Unifews/data/processed/amazon_computers (2)/feats.npy
# /content/Unifews/data/processed/amazon_computers (1)/feats.npy
# /content/Unifews/data/processed/amazon_computers/feats.npy
# /content/Unifews/data/processed/cs/feats.npy
# /content/Unifews/data/cs/feats.npy
# /content/Unifews/data/cora/adj.npz
# /content/Unifews/data/cora/labels.npz
# /content/Unifews/data/cora/degree.npz
# /content/Unifews/data/raw/Amazon/Computers/raw/amazon_electronics_computers.npz
# /content/Unifews/data/raw/Coauthor/CS/raw/ms_academic_cs.npz
# /content/Unifews/data/computers/adj.npz
# /content/Unifews/data/computers/labels.npz
# /content/Unifews/data/computers/degree.npz
# /content/Unifews/data/processed/amazon_computers (2)/adj.npz
# /content/Unifews/data/processed/amazon_computers (2)/labels.npz
# /content/Unifews/data/processed/amazon_computers (2)/degree.npz
# /content/Unifews/data/processed/raw/Amazon/Computers/raw/amazon_electronics_computers.npz
# /content/Unifews/data/processed/amazon_computers (1)/adj.npz
# /content/Unifews/data/processed/amazon_computers (1)/labels.npz
# /content/Unifews/data/processed/amazon_computers (1)/degree.npz
# /content/Unifews/data/processed/amazon_computers/adj.npz
# /content/Unifews/data/processed/amazon_computers/labels.npz
# /content/Unifews/data/processed/amazon_computers/degree.npz
# /content/Unifews/data/processed/cs/adj.npz
# /content/Unifews/data/processed/cs/labels.npz
# /content/Unifews/data/processed/cs/degree.npz
# /content/Unifews/data/cs/adj.npz
# /content/Unifews/data/cs/labels.npz
# /content/Unifews/data/cs/degree.npz

# %%
# !python utils/data_transfer.py --dataset cs
# Out:
# This will download 56.17GB. Will you proceed? (y/N)

# %%
# !python run_fbb.py -f 42 -c cs_sgc_table_thr -v 0

# %%
# !python run_fbb.py -f 42 -c cs_sgc_table -v 0
# Out:
# Option saved.
# Config path: ./save/cs/sgc/42-0.0e+00-0.0e+00/config.json
# Option dict: {'data': 'cs', 'path': './data/', 'algo': 'sgc', 'epochs': 200, 'patience': 20, 'lr': 0.01, 'weight_decay': 1e-05, 'layer': 2, 'hidden': 512, 'dropout': 0.5, 'thr_a': 0.0, 'thr_w': 0.0, 'chn': {'hop': 20, 'alpha': 0.0, 'rrz': 0.5}, 'seed': 42, 'dev': 0, 'config': 'cs_sgc_table', 'suffix': ''}
#
# n=18333, m=163788, F=6805, C=15 | feat: (18333, 6805), label: (18333,) | 9166/4583/4584=0.50/0.25/0.25
# n=18333, m=163788, F=6805, C=15 | feat: (18333, 6805), label: (18333,) | 9166/4583/4584=0.50/0.25/0.25
# MLP sgc 0.0 0.0
# MLP(
#   (dropout): Dropout(p=0.5, inplace=False)
#   (act): ReLU(inplace=True)
#   (fcs): ModuleList(
#     (0): Linear(in_features=6805, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=15, bias=True)
#   )
#   (bns): ModuleList(
#     (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Epoch:0001 | train loss:2.9960, val acc:0.8071, time:0.5779, macs:64.0631
# Epoch:0002 | train loss:0.5721, val acc:0.8776, time:0.6155, macs:128.1262
# Epoch:0003 | train loss:0.3945, val acc:0.9108, time:0.6588, macs:192.1893
# Epoch:0004 | train loss:0.3246, val acc:0.9245, time:0.6831, macs:256.2524
# Epoch:0005 | train loss:0.2679, val acc:0.9319, time:0.7077, macs:320.3156
# Epoch:0006 | train loss:0.2097, val acc:0.9352, time:0.7310, macs:384.3787
# Epoch:0007 | train loss:0.1714, val acc:0.9358, time:0.7545, macs:448.4418
# Epoch:0008 | train loss:0.1469, val acc:0.9376, time:0.7842, macs:512.5049
# Epoch:0009 | train loss:0.1289, val acc:0.9389, time:0.8077, macs:576.5680
# Epoch:0010 | train loss:0.1144, val acc:0.9393, time:0.8324, macs:640.6311
# Epoch:0011 | train loss:0.1020, val acc:0.9404, time:0.8659, macs:704.6942
# Epoch:0012 | train loss:0.0882, val acc:0.9426, time:0.8982, macs:768.7573
# Epoch:0013 | train loss:0.0728, val acc:0.9452, time:0.9394, macs:832.8204
# Epoch:0014 | train loss:0.0660, val acc:0.9448, time:0.9633, macs:896.8835
# Epoch:0015 | train loss:0.0536, val acc:0.9457, time:0.9869, macs:960.9467
# Epoch:0016 | train loss:0.0496, val acc:0.9472, time:1.0172, macs:1025.0098
# Epoch:0017 | train loss:0.0428, val acc:0.9465, time:1.0411, macs:1089.0729
# Epoch:0018 | train loss:0.0370, val acc:0.9472, time:1.0653, macs:1153.1360
# Epoch:0019 | train loss:0.0328, val acc:0.9476, time:1.0902, macs:1217.1991
# Epoch:0020 | train loss:0.0306, val acc:0.9474, time:1.1144, macs:1281.2622
# Epoch:0021 | train loss:0.0277, val acc:0.9483, time:1.1382, macs:1345.3253
# Epoch:0022 | train loss:0.0236, val acc:0.9494, time:1.1625, macs:1409.3884
# Epoch:0023 | train loss:0.0205, val acc:0.9489, time:1.1873, macs:1473.4515
# Epoch:0024 | train loss:0.0171, val acc:0.9494, time:1.2121, macs:1537.5146
# Epoch:0025 | train loss:0.0161, val acc:0.9485, time:1.2354, macs:1601.5778
# Epoch:0026 | train loss:0.0161, val acc:0.9481, time:1.2618, macs:1665.6409
# Epoch:0027 | train loss:0.0122, val acc:0.9474, time:1.2857, macs:1729.7040
# Epoch:0028 | train loss:0.0124, val acc:0.9470, time:1.3095, macs:1793.7671
# Epoch:0029 | train loss:0.0105, val acc:0.9476, time:1.3343, macs:1857.8302
# Epoch:0030 | train loss:0.0100, val acc:0.9483, time:1.3587, macs:1921.8933
# Epoch:0031 | train loss:0.0087, val acc:0.9485, time:1.3841, macs:1985.9564
# Epoch:0032 | train loss:0.0086, val acc:0.9494, time:1.4080, macs:2050.0195
# Epoch:0033 | train loss:0.0067, val acc:0.9494, time:1.4322, macs:2114.0826
# Epoch:0034 | train loss:0.0074, val acc:0.9492, time:1.4572, macs:2178.1457
# Epoch:0035 | train loss:0.0059, val acc:0.9489, time:1.4829, macs:2242.2089
# Epoch:0036 | train loss:0.0057, val acc:0.9489, time:1.5080, macs:2306.2720
# Epoch:0037 | train loss:0.0048, val acc:0.9489, time:1.5351, macs:2370.3351
# Epoch:0038 | train loss:0.0052, val acc:0.9494, time:1.5623, macs:2434.3982
# Epoch:0039 | train loss:0.0056, val acc:0.9492, time:1.5934, macs:2498.4613
# Epoch:0040 | train loss:0.0046, val acc:0.9489, time:1.6271, macs:2562.5244
# Epoch:0041 | train loss:0.0041, val acc:0.9489, time:1.6742, macs:2626.5875
# Epoch:0042 | train loss:0.0052, val acc:0.9489, time:1.7090, macs:2690.6506
# Epoch:0043 | train loss:0.0041, val acc:0.9492, time:1.7334, macs:2754.7137
# Epoch:0044 | train loss:0.0040, val acc:0.9494, time:1.7572, macs:2818.7768
# Epoch:0045 | train loss:0.0043, val acc:0.9498, time:1.7829, macs:2882.8400
# Epoch:0046 | train loss:0.0034, val acc:0.9503, time:1.8114, macs:2946.9031
# Epoch:0047 | train loss:0.0040, val acc:0.9500, time:1.8360, macs:3010.9662
# Epoch:0048 | train loss:0.0048, val acc:0.9500, time:1.8608, macs:3075.0293
# Epoch:0049 | train loss:0.0035, val acc:0.9500, time:1.8854, macs:3139.0924
# Epoch:0050 | train loss:0.0035, val acc:0.9500, time:1.9110, macs:3203.1555
# Epoch:0051 | train loss:0.0031, val acc:0.9500, time:1.9356, macs:3267.2186
# Epoch:0052 | train loss:0.0030, val acc:0.9500, time:1.9593, macs:3331.2817
# Epoch:0053 | train loss:0.0035, val acc:0.9500, time:1.9896, macs:3395.3448
# Epoch:0054 | train loss:0.0043, val acc:0.9498, time:2.0137, macs:3459.4080
# Epoch:0055 | train loss:0.0038, val acc:0.9498, time:2.0373, macs:3523.4711
# Epoch:0056 | train loss:0.0029, val acc:0.9498, time:2.0616, macs:3587.5342
# Epoch:0057 | train loss:0.0030, val acc:0.9500, time:2.0860, macs:3651.5973
# Epoch:0058 | train loss:0.0029, val acc:0.9500, time:2.1098, macs:3715.6604
# Epoch:0059 | train loss:0.0032, val acc:0.9500, time:2.1336, macs:3779.7235
# Epoch:0060 | train loss:0.0032, val acc:0.9500, time:2.1594, macs:3843.7866
# Epoch:0061 | train loss:0.0030, val acc:0.9498, time:2.1828, macs:3907.8497
# Epoch:0062 | train loss:0.0026, val acc:0.9496, time:2.2076, macs:3971.9128
# Epoch:0063 | train loss:0.0027, val acc:0.9494, time:2.2359, macs:4035.9759
# Epoch:0064 | train loss:0.0026, val acc:0.9494, time:2.2614, macs:4100.0391
# Epoch:0065 | train loss:0.0026, val acc:0.9494, time:2.2930, macs:4164.1022
# Epoch:0066 | train loss:0.0031, val acc:0.9494, time:2.3195, macs:4228.1653
# Epoch:0067 | train loss:0.0031, val acc:0.9494, time:2.3503, macs:4292.2284
# Epoch:0068 | train loss:0.0028, val acc:0.9494, time:2.3750, macs:4356.2915
# Epoch:0069 | train loss:0.0024, val acc:0.9494, time:2.4024, macs:4420.3546
# Epoch:0070 | train loss:0.0031, val acc:0.9494, time:2.4273, macs:4484.4177
# Epoch:0071 | train loss:0.0030, val acc:0.9492, time:2.4516, macs:4548.4808
# Epoch:0072 | train loss:0.0024, val acc:0.9492, time:2.4754, macs:4612.5439
# Epoch:0073 | train loss:0.0025, val acc:0.9492, time:2.4995, macs:4676.6070
# Epoch:0074 | train loss:0.0027, val acc:0.9492, time:2.5237, macs:4740.6702
# Epoch:0075 | train loss:0.0028, val acc:0.9492, time:2.5684, macs:4804.7333
# Epoch:0076 | train loss:0.0025, val acc:0.9492, time:2.5936, macs:4868.7964
# Epoch:0077 | train loss:0.0026, val acc:0.9492, time:2.6320, macs:4932.8595
# Epoch:0078 | train loss:0.0027, val acc:0.9492, time:2.6552, macs:4996.9226
# Epoch:0079 | train loss:0.0026, val acc:0.9492, time:2.6794, macs:5060.9857
# Epoch:0080 | train loss:0.0024, val acc:0.9494, time:2.7034, macs:5125.0488
# Epoch:0081 | train loss:0.0027, val acc:0.9494, time:2.7290, macs:5189.1119
# Epoch:0082 | train loss:0.0022, val acc:0.9494, time:2.7524, macs:5253.1750
# Epoch:0083 | train loss:0.0029, val acc:0.9494, time:2.7788, macs:5317.2381
# Epoch:0084 | train loss:0.0026, val acc:0.9494, time:2.8059, macs:5381.3013
# Epoch:0085 | train loss:0.0026, val acc:0.9494, time:2.8297, macs:5445.3644
# Epoch:0086 | train loss:0.0027, val acc:0.9494, time:2.8571, macs:5509.4275
# Epoch:0087 | train loss:0.0025, val acc:0.9494, time:2.8825, macs:5573.4906
# Epoch:0088 | train loss:0.0025, val acc:0.9496, time:2.9060, macs:5637.5537
# Epoch:0089 | train loss:0.0025, val acc:0.9496, time:2.9439, macs:5701.6168
# Epoch:0090 | train loss:0.0028, val acc:0.9496, time:2.9699, macs:5765.6799
# Epoch:0091 | train loss:0.0023, val acc:0.9496, time:3.0012, macs:5829.7430
# Epoch:0092 | train loss:0.0028, val acc:0.9496, time:3.0254, macs:5893.8061
# Epoch:0093 | train loss:0.0022, val acc:0.9494, time:3.0589, macs:5957.8692
# Epoch:0094 | train loss:0.0022, val acc:0.9494, time:3.0892, macs:6021.9324
# Epoch:0095 | train loss:0.0026, val acc:0.9494, time:3.1175, macs:6085.9955
# Epoch:0096 | train loss:0.0027, val acc:0.9494, time:3.1478, macs:6150.0586
# Epoch:0097 | train loss:0.0025, val acc:0.9494, time:3.1750, macs:6214.1217
# Epoch:0098 | train loss:0.0023, val acc:0.9494, time:3.2025, macs:6278.1848
# Epoch:0099 | train loss:0.0022, val acc:0.9494, time:3.2354, macs:6342.2479
# Epoch:0100 | train loss:0.0024, val acc:0.9494, time:3.2596, macs:6406.3110
# Epoch:0101 | train loss:0.0031, val acc:0.9494, time:3.2846, macs:6470.3741
# Epoch:0102 | train loss:0.0026, val acc:0.9494, time:3.3118, macs:6534.4372
# Epoch:0103 | train loss:0.0024, val acc:0.9494, time:3.3360, macs:6598.5004
# Epoch:0104 | train loss:0.0022, val acc:0.9494, time:3.3605, macs:6662.5635
# Epoch:0105 | train loss:0.0024, val acc:0.9494, time:3.3899, macs:6726.6266
# Epoch:0106 | train loss:0.0026, val acc:0.9494, time:3.4136, macs:6790.6897
# Epoch:0107 | train loss:0.0028, val acc:0.9494, time:3.4378, macs:6854.7528
# Epoch:0108 | train loss:0.0027, val acc:0.9494, time:3.4839, macs:6918.8159
# Epoch:0109 | train loss:0.0027, val acc:0.9494, time:3.5073, macs:6982.8790
# Epoch:0110 | train loss:0.0024, val acc:0.9494, time:3.5308, macs:7046.9421
# Epoch:0111 | train loss:0.0023, val acc:0.9494, time:3.5563, macs:7111.0052
# Epoch:0112 | train loss:0.0022, val acc:0.9494, time:3.5806, macs:7175.0683
# Epoch:0113 | train loss:0.0023, val acc:0.9494, time:3.6044, macs:7239.1315
# Epoch:0114 | train loss:0.0022, val acc:0.9494, time:3.6295, macs:7303.1946
# Epoch:0115 | train loss:0.0026, val acc:0.9494, time:3.6536, macs:7367.2577
# Epoch:0116 | train loss:0.0022, val acc:0.9494, time:3.6828, macs:7431.3208
# Epoch:0117 | train loss:0.0032, val acc:0.9494, time:3.7159, macs:7495.3839
# Epoch:0118 | train loss:0.0024, val acc:0.9494, time:3.7444, macs:7559.4470
# Epoch:0119 | train loss:0.0023, val acc:0.9494, time:3.7682, macs:7623.5101
# Epoch:0120 | train loss:0.0023, val acc:0.9494, time:3.7932, macs:7687.5732
# Epoch:0121 | train loss:0.0028, val acc:0.9494, time:3.8188, macs:7751.6363
# Epoch:0122 | train loss:0.0023, val acc:0.9494, time:3.8572, macs:7815.6994
# Epoch:0123 | train loss:0.0023, val acc:0.9494, time:3.8928, macs:7879.7626
# Epoch:0124 | train loss:0.0024, val acc:0.9494, time:3.9204, macs:7943.8257
# Epoch:0125 | train loss:0.0022, val acc:0.9494, time:3.9485, macs:8007.8888
# Epoch:0126 | train loss:0.0025, val acc:0.9494, time:3.9742, macs:8071.9519
# Epoch:0127 | train loss:0.0023, val acc:0.9494, time:3.9993, macs:8136.0150
# Epoch:0128 | train loss:0.0029, val acc:0.9494, time:4.0274, macs:8200.0781
# Epoch:0129 | train loss:0.0025, val acc:0.9494, time:4.0518, macs:8264.1412
# Epoch:0130 | train loss:0.0026, val acc:0.9494, time:4.0908, macs:8328.2043
# Epoch:0131 | train loss:0.0022, val acc:0.9494, time:4.1220, macs:8392.2674
# Epoch:0132 | train loss:0.0026, val acc:0.9494, time:4.1473, macs:8456.3305
# Epoch:0133 | train loss:0.0023, val acc:0.9494, time:4.1734, macs:8520.3937
# Traceback (most recent call last):
#   File "/content/Unifews/run_fbb.py", line 214, in <module>
#     acc_val, _, _, _ = eval(x=feat['train'], edge_idx=adj['train'],
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Unifews/run_fbb.py", line 154, in eval
#     x, y = x.cuda(args.dev), y.cuda(args.dev)
#            ^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !python run_fbb.py -f 42 -c cs_appnp_table_thr -v 0
# Out:
# Traceback (most recent call last):
#   File "/content/Unifews/run_fbb.py", line 7, in <module>
#     import ptflops
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/__init__.py", line 10, in <module>
#     from .flops_counter import FLOPS_BACKEND, get_model_complexity_info
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/flops_counter.py", line 15, in <module>
#     from .aten_engine import get_flops_aten
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/aten_engine.py", line 20, in <module>
#     from ptflops.pytorch_engine import get_model_parameters_number
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/pytorch_engine.py", line 18, in <module>
#     from .pytorch_ops import (CUSTOM_MODULES_MAPPING, FUNCTIONAL_MAPPING, MODULES_MAPPING,
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/pytorch_ops.py", line 327, in <module>
#     import torchvision.ops as tops
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/__init__.py", line 10, in <module>
#     from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/models/__init__.py", line 2, in <module>
#     from .convnext import *
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/models/convnext.py", line 9, in <module>
#     from ..ops.misc import Conv2dNormActivation, Permute
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/ops/__init__.py", line 1, in <module>
#     from ._register_onnx_ops import _register_custom_op
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/ops/_register_onnx_ops.py", line 5, in <module>
#     from torch.onnx import symbolic_opset11 as opset11
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/__init__.py", line 27, in <module>
#     from . import errors, ops
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/ops/__init__.py", line 23, in <module>
#     from torch.onnx.ops import _impl, _symbolic_impl
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/ops/_impl.py", line 67, in <module>
#     @_onnx_op("RotaryEmbedding", 23, _rotary_embedding_23_fake_impl)
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/ops/_impl.py", line 41, in decorator
#     torch_op = torch.library.custom_op(
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_library/custom_ops.py", line 157, in inner
#     result = CustomOpDef(namespace, opname, schema_str, fn, tags)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_library/custom_ops.py", line 215, in __init__
#     self._register_to_dispatcher(self._tags)
#   File "/usr/local/lib/python3.12/dist-packages/torch/_library/custom_ops.py", line 638, in _register_to_dispatcher
#     lib._register_fake(self._name, fake_impl, _stacklevel=4)
#   File "/usr/local/lib/python3.12/dist-packages/torch/library.py", line 182, in _register_fake
#     source = torch._library.utils.get_source(_stacklevel + 1)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_library/utils.py", line 45, in get_source
#     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 1718, in getframeinfo
#     lines, lnum = findsource(frame)
#                   ^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 1090, in findsource
#     module = getmodule(object, file)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 1007, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
# !python run_fbb.py -f 42 -c cs_appnp_table -v 0
# Out:
# Traceback (most recent call last):
#   File "/content/Unifews/run_fbb.py", line 7, in <module>
#     import ptflops
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/__init__.py", line 10, in <module>
#     from .flops_counter import FLOPS_BACKEND, get_model_complexity_info
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/flops_counter.py", line 13, in <module>
#     import torch.nn as nn
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 2247, in <module>
#     from torch import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/hub.py", line 64, in <module>
#     from tqdm import tqdm  # If tqdm is installed use it, otherwise use the fake wrapper
#     ^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 921, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 819, in module_from_spec
#   File "<frozen importlib._bootstrap>", line 733, in _init_module_attrs
# KeyboardInterrupt
# ^C

# %%
# !python run_fbb.py -f 42 -c computers_sgc_table -v 0
# Out:
# Traceback (most recent call last):
# object address  : 0x7abd87f6ace0
# object refcount : 3
# object type     : 0xa284e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C

# %%
# !python run_fbb.py -f 42 -c computers_sgc_table_thr -v 0
# Out:
# Traceback (most recent call last):
# object address  : 0x7cab4c7029e0
# object refcount : 3
# object type     : 0xa284e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr

# %%
# !python run_fbb.py -f 42 -c computers_appnp_table_thr -v 0
# Out:
# Traceback (most recent call last):
#   File "/content/Unifews/run_fbb.py", line 7, in <module>
#     import ptflops
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/__init__.py", line 10, in <module>
#     from .flops_counter import FLOPS_BACKEND, get_model_complexity_info
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/flops_counter.py", line 13, in <module>
#     import torch.nn as nn
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 2785, in <module>
#     from torch import _meta_registrations
#   File "/usr/local/lib/python3.12/dist-packages/torch/_meta_registrations.py", line 758, in <module>
#     @register_meta([aten.max.default, aten.max.unary_out])
#                                       ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_ops.py", line 1180, in __getattr__
#     if not _has_script_object_arg(schema)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_ops.py", line 1091, in _has_script_object_arg
#     return any(isinstance(arg.type, torch.ClassType) for arg in schema.arguments)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_ops.py", line 1091, in <genexpr>
#     return any(isinstance(arg.type, torch.ClassType) for arg in schema.arguments)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
# !python run_fbb.py -f 42 -c computers_appnp_table -v 0
# Out:
# Traceback (most recent call last):
#   File "/content/Unifews/run_fbb.py", line 7, in <module>
#     import ptflops
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/__init__.py", line 10, in <module>
#     from .flops_counter import FLOPS_BACKEND, get_model_complexity_info
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/flops_counter.py", line 13, in <module>
#     import torch.nn as nn
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 2319, in <module>
#     from torch import quantization as quantization  # usort: skip
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/quantization/__init__.py", line 2, in <module>
#     from .fake_quantize import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/quantization/fake_quantize.py", line 10, in <module>
#     from torch.ao.quantization.fake_quantize import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/ao/quantization/__init__.py", line 14, in <module>
#     from .pt2e._numeric_debugger import (  # noqa: F401
#   File "/usr/local/lib/python3.12/dist-packages/torch/ao/quantization/pt2e/_numeric_debugger.py", line 8, in <module>
#     from torch.ao.quantization.pt2e.graph_utils import bfs_trace_with_node_process
#   File "/usr/local/lib/python3.12/dist-packages/torch/ao/quantization/pt2e/graph_utils.py", line 9, in <module>
#     from torch.export import ExportedProgram
#   File "/usr/local/lib/python3.12/dist-packages/torch/export/__init__.py", line 11, in <module>
#     from torch.fx.passes.infra.pass_base import PassResult
#   File "/usr/local/lib/python3.12/dist-packages/torch/fx/passes/__init__.py", line 1, in <module>
#     from . import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/fx/passes/graph_drawer.py", line 14, in <module>
#     from torch.fx.passes.shape_prop import TensorMetadata
#   File "/usr/local/lib/python3.12/dist-packages/torch/fx/passes/shape_prop.py", line 11, in <module>
#     from torch._subclasses.meta_utils import is_sparse_any
#   File "/usr/local/lib/python3.12/dist-packages/torch/_subclasses/__init__.py", line 2, in <module>
#     from torch._subclasses.fake_tensor import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_subclasses/fake_tensor.py", line 61, in <module>
#     from ._fake_tensor_utils import _CacheKeyState, _PySymInputStub, _SymIntOutputStub
#   File "/usr/local/lib/python3.12/dist-packages/torch/_subclasses/_fake_tensor_utils.py", line 108, in <module>
#     @dataclass(frozen=True, slots=True)
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/dataclasses.py", line 1265, in wrap
#     return _process_class(cls, init, repr, eq, order, unsafe_hash,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/dataclasses.py", line 1063, in _process_class
#     _init_fn(all_init_fields,
#   File "/usr/lib/python3.12/dataclasses.py", line 619, in _init_fn
#     return _create_fn('__init__',
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/dataclasses.py", line 473, in _create_fn
#     exec(txt, globals, ns)
#   File "<string>", line 0, in <module>
# KeyboardInterrupt
# ^C

# %%
# !python run_fbb.py -f 42 -c cora_sgc_table -v 0
# Out:
# Traceback (most recent call last):
#   File "/content/Unifews/run_fbb.py", line 7, in <module>
#     import ptflops
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/__init__.py", line 10, in <module>
#     from .flops_counter import FLOPS_BACKEND, get_model_complexity_info
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/flops_counter.py", line 13, in <module>
#     import torch.nn as nn
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 1091, in <module>
#     _import_extension_to_sys_modules(_C)
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 1085, in _import_extension_to_sys_modules
#     member_name = getattr(member, "__name__", "")
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
# !python run_fbb.py -f 42 -c cora_sgc_table_thr -v 0
# Out:
# Traceback (most recent call last):
#   File "/content/drive/.shortcut-targets-by-id/1_5kJLcXJuln6Z3yserbXXe9tK4T6UFOZ/Project/Unifews/run_fbb.py", line 40, in <module>
#     with torch.cuda.device(args.dev):
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 550, in __enter__
#     self.prev_idx = torch.cuda._exchange_device(self.idx)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 137, in _exchange_device
#     raise RuntimeError("PyTorch was compiled without CUDA support")
# RuntimeError: PyTorch was compiled without CUDA support

# %%
# !python run_fbb.py -f 42 -c cora_appnp_table_thr -v 0
# Out:
# Traceback (most recent call last):
#   File "/content/drive/.shortcut-targets-by-id/1_5kJLcXJuln6Z3yserbXXe9tK4T6UFOZ/Project/Unifews/run_fbb.py", line 40, in <module>
#     with torch.cuda.device(args.dev):
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 550, in __enter__
#     self.prev_idx = torch.cuda._exchange_device(self.idx)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 137, in _exchange_device
#     raise RuntimeError("PyTorch was compiled without CUDA support")
# RuntimeError: PyTorch was compiled without CUDA support

# %%
# !python run_fbb.py -f 42 -c cora_appnp_table -v 0
# Out:
# Traceback (most recent call last):
#   File "/content/Unifews/run_fbb.py", line 7, in <module>
#     import ptflops
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/__init__.py", line 10, in <module>
#     from .flops_counter import FLOPS_BACKEND, get_model_complexity_info
#   File "/usr/local/lib/python3.12/dist-packages/ptflops/flops_counter.py", line 13, in <module>
#     import torch.nn as nn
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 2319, in <module>
#     from torch import quantization as quantization  # usort: skip
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/quantization/__init__.py", line 2, in <module>
#     from .fake_quantize import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/quantization/fake_quantize.py", line 10, in <module>
#     from torch.ao.quantization.fake_quantize import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/ao/quantization/__init__.py", line 14, in <module>
#     from .pt2e._numeric_debugger import (  # noqa: F401
#   File "/usr/local/lib/python3.12/dist-packages/torch/ao/quantization/pt2e/_numeric_debugger.py", line 8, in <module>
#     from torch.ao.quantization.pt2e.graph_utils import bfs_trace_with_node_process
#   File "/usr/local/lib/python3.12/dist-packages/torch/ao/quantization/pt2e/graph_utils.py", line 9, in <module>
#     from torch.export import ExportedProgram
#   File "/usr/local/lib/python3.12/dist-packages/torch/export/__init__.py", line 42, in <module>
#     from .decomp_utils import CustomDecompTable
#   File "/usr/local/lib/python3.12/dist-packages/torch/export/decomp_utils.py", line 5, in <module>
#     from torch._export.utils import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_export/__init__.py", line 49, in <module>
#     from .wrappers import _wrap_submodules
#   File "/usr/local/lib/python3.12/dist-packages/torch/_export/wrappers.py", line 10, in <module>
#     from torch._higher_order_ops.flat_apply import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_higher_order_ops/__init__.py", line 1, in <module>
#     from torch._higher_order_ops._invoke_quant import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_higher_order_ops/_invoke_quant.py", line 8, in <module>
#     from torch._higher_order_ops.base_hop import BaseHOP, FunctionWithNoFreeVars
#   File "/usr/local/lib/python3.12/dist-packages/torch/_higher_order_ops/base_hop.py", line 9, in <module>
#     from torch._higher_order_ops.auto_functionalize import FunctionalCallableWithEpilogue
#   File "/usr/local/lib/python3.12/dist-packages/torch/_higher_order_ops/auto_functionalize.py", line 13, in <module>
#     from torch._higher_order_ops.utils import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_higher_order_ops/utils.py", line 14, in <module>
#     from torch._higher_order_ops.schema import HopSchema
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1128, in get_code
#   File "<frozen importlib._bootstrap_external>", line 757, in _compile_bytecode
# KeyboardInterrupt
# ^C

# %%
# !ls -lh data/cs/
# Out:
# total 479M
# -rw------- 1 root root 640K Mar 28 01:58 adj_el.bin
# -rw------- 1 root root 394K Mar 28 01:58 adj.npz
# -rw------- 1 root root  72K Mar 28 01:58 adj_pl.bin
# -rw------- 1 root root 1.7M Mar 28 01:58 adj.txt
# -rw------- 1 root root  18K Mar 28 01:58 degree.npz
# -rw------- 1 root root 476M Mar 28 01:58 feats.npy
# -rw------- 1 root root  63K Mar 28 01:58 labels.npz

# %% [markdown]
# # Amazon

# %%
import os
import numpy as np
import scipy.sparse as sp
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from typing import Optional, List


NTRAIN_PER_CLASS = 20
NVAL_PER_CLASS = NTRAIN_PER_CLASS * 10


# ====================
def diag_sp(diag) -> sp.dia_matrix:
    """Diagonal array to scipy sparse diagonal matrix"""
    n = len(diag)
    return sp.dia_matrix((diag, [0]), shape=(n, n))


def to_torch_sparse(x: sp.coo_matrix):
    import torch
    x = x.tocoo()
    shape = x.shape
    i = torch.LongTensor(np.vstack((x.row, x.col)))
    v = torch.FloatTensor(x.data)
    return torch.sparse.FloatTensor(i, v, torch.Size(shape))


def matstd(m, with_mean=False):
    """Matrix standardization"""
    scaler = StandardScaler(with_mean=with_mean)
    m = scaler.fit_transform(m)
    return m


def matnorm_inf_dual(m, axis=0):
    """Normalization of matrix, set positive/negative sum of column to 1
    """
    pos = m.clip(min=0)
    possum = pos.sum(axis=axis)
    possum[possum == 0] = 1         # Avoid sum = 0
    pos = pos / possum

    neg = m.clip(max=0)
    negsum = - neg.sum(axis=axis)
    negsum[negsum == 0] = 1         # Avoid sum = 0
    neg = neg / negsum
    return (pos + neg)


def matstd_clip(m, idx, with_mean=False, clip=False):
    """Standardize and clip per feature"""
    # idx = np.setdiff1d(idx, [0])
    if (len(idx) > 0.75 * m.shape[0]) and (m.shape[0] > 2e9):
        idx = np.random.choice(idx, size=int(len(idx)/5), replace=False)
    scaler = StandardScaler(with_mean=with_mean)
    scaler.fit(m[idx])
    if clip:
        mean, std = scaler.mean_, scaler.scale_
        k = 9
        m = np.clip(m, a_min=mean-k*std, a_max=mean+k*std)
    m = scaler.transform(m)
    return m


def edgeidx2adj(row, col, n, undirected=False):
    if undirected:
        row, col = np.concatenate([row, col], axis=0), np.concatenate([col, row], axis=0)
    ones = np.ones(len(row), dtype=np.int8)
    adj = sp.coo_matrix(
            (ones, (row, col)),
            shape=(n, n))
    adj = adj.tocsr()
    adj.setdiag(0)
    adj.eliminate_zeros()
    adj.data = np.ones(len(adj.data), dtype=np.int8)
    return adj


def split_random(seed, n, n_train, n_val):
    """Split index randomly"""
    np.random.seed(seed)
    rnd = np.random.permutation(n)

    train_idx = np.sort(rnd[:n_train])
    val_idx = np.sort(rnd[n_train:n_train + n_val])

    train_val_idx = np.concatenate((train_idx, val_idx))
    test_idx = np.sort(np.setdiff1d(np.arange(n), train_val_idx))
    return train_idx, val_idx, test_idx


def split_label(seed, n, n_train_per_class, n_val, labels):
    """Split index with equal label in train set"""
    np.random.seed(seed)
    rnd = set(np.arange(n))

    train_idx = np.array([], dtype=int)
    if labels.ndim == 1:
        lb_nonnan = labels[~np.isnan(labels)]
        nclass = int(lb_nonnan.max()) + 1
        for i in range(nclass):
            cdd = np.where(labels == i)[0]
            sz = min(n_train_per_class, len(cdd))
            idxi = np.random.choice(cdd, size=sz, replace=False)
            train_idx = np.concatenate((train_idx, idxi))
    else:
        nclass = labels.shape[1]
        for i in range(nclass):
            cdd = np.where(labels[:, i] > 0)[0]
            sz = min(n_train_per_class, len(cdd))
            idxi = np.random.choice(cdd, size=sz, replace=False)
            train_idx = np.concatenate((train_idx, idxi))

    train_idx = np.unique(train_idx.flatten(), axis=0)
    val_idx = np.array((list( rnd - set(train_idx) )))
    val_idx = np.random.choice(val_idx, size=n_val, replace=False)
    val_idx = np.sort(val_idx)

    train_val_idx = np.concatenate((train_idx, val_idx))
    test_idx = np.sort(np.setdiff1d(np.arange(n), train_val_idx))
    return train_idx, val_idx, test_idx


def split_stratify(seed, n, n_train, n_val, labels):
    assert labels.ndim == 1, 'Only support 1D labels'
    idx = np.arange(n)
    train_idx, test_idx = train_test_split(idx, train_size=n_train, random_state=seed, stratify=labels)
    val_idx, test_idx = train_test_split(test_idx, train_size=n_val, random_state=seed, stratify=labels[test_idx])
    return train_idx, val_idx, test_idx


# ====================
class DataProcess(object):
    def __init__(self, name: str, path: str='../data/', rrz: float=0.5, seed: int=0) -> None:
        super().__init__()
        self.name = name
        self.path = path
        self.rrz = rrz
        self.seed = seed

        self._n = None
        self._m = None
        self._nfeat = None
        self._nclass = None

        self.adjnpz_path = self._get_path('adj.npz')
        self.adjtxt_path = self._get_path('adj.txt')
        self.degree_path = self._get_path('degree.npz')
        self.labels_path = self._get_path('labels.npz')
        self.query_path = self._get_path('query.txt')
        self.querytrain_path = self._get_path('query_train.txt')
        self.feats_path = self._get_path('feats.npy')
        self.featsnorm_path = self._get_path(f'feats_normt_{self.rrz:g}.npy')

        self.adj_matrix = None
        self.deg = None
        self.labels = None              # Labels can be 1D array or 2D one hot
        self.idx_train = None
        self.idx_val = None
        self.idx_test = None
        self.attr_matrix = None
        self.attr_matrix_norm = None

    def _get_path(self, fname):
        return os.path.join(self.path, self.name, fname)

    @property
    def n(self) -> int:
        if self._n:
            return self._n
        # 1. Use cache adj matrix
        if self.adj_matrix is not None:
            self._n = self.adj_matrix.shape[0]
        # 2: Use attribute file
        elif os.path.isfile(self._get_path('attribute.txt')):
            with open(self._get_path('attribute.txt'), 'r') as attr_f:
                nline = attr_f.readline().rstrip()
            self._n = int(''.join(filter(str.isdigit, nline)))
        # 3: Use label length | WARNING: incorrect for inductive dataset
        elif self.labels is not None:
            self._n = len(self.labels)
        return self._n

    @property
    def n_train(self) -> int:
        return len(self.idx_train)

    @property
    def n_val(self) -> int:
        return len(self.idx_val)

    @property
    def n_test(self) -> int:
        return len(self.idx_test)

    @property
    def m(self) -> int:
        if self._m:
            return self._m
        # 1: Use cache adj matrix
        if self.adj_matrix is not None:
            self._m = self.adj_matrix.nnz
        # 2: Use attribute file
        elif os.path.isfile(self._get_path('attribute.txt')):
            with open(self._get_path('attribute.txt'), 'r') as attr_f:
                nline = attr_f.readline().rstrip()
                mline = attr_f.readline().rstrip()
            self._m = int(''.join(filter(str.isdigit, mline)))
        # 3: Count by wc -l
        else:
            import subprocess
            self._m = int(subprocess.check_output(["wc", "-l", self.adjtxt_path]).split()[0])
        return self._m

    @property
    def nfeat(self) -> int:
        if self._nfeat:
            return self._nfeat
        if self.attr_matrix is None:
            self.input(['attr_matrix'])
        self._nfeat = self.attr_matrix.shape[1]
        return self._nfeat

    @property
    def nclass(self) -> int:
        if self._nclass:
            return self._nclass
        if self.labels is None:
            self.input(['labels'])
        # 1D array
        if self.labels.ndim == 1:
            # self._nclass = int(self.labels.max()) + 1
            lb_nonnan = self.labels[~np.isnan(self.labels)]
            self._nclass = int(lb_nonnan.max()) + 1
        # 2D one hot
        else:
            self._nclass = self.labels.shape[1]
        return self._nclass

    def __str__(self) -> str:
        s  = f"n={self.n}, m={self.m}, F={self.nfeat}, C={self.nclass} | "
        s += f"feat: {self.attr_matrix.shape}, label: {self.labels.shape} | "
        s += f"{self.n_train}/{self.n_val}/{self.n_test}="
        s += f"{self.n_train/self.n:0.2f}/{self.n_val/self.n:0.2f}/{self.n_test/self.n:0.2f}"
        return s

    def calculate(self, lst: List[str]) -> None:
        for key in lst:
            if key == 'deg':
                assert self.adj_matrix is not None
                assert np.sum(self.adj_matrix.diagonal()) == 0
                self.deg = self.adj_matrix.sum(1).A1
            elif key in ['idx_train', 'idx_val', 'idx_test']:
                # n_train = NTRAIN_PER_CLASS * self.nclass
                # n_val = NVAL_PER_CLASS * self.nclass
                n_train = int(0.50 * self.n)
                n_val = int(0.25 * self.n)
                if 'paper' == self.name:
                    np.random.seed(self.seed)
                    self.input(['idx_train', 'idx_val', 'idx_test'])
                    rnd = np.concatenate((self.idx_train, self.idx_val, self.idx_test))
                    rnd = np.random.permutation(rnd)
                    self.idx_train = np.sort(rnd[:n_train])
                    self.idx_val = np.sort(rnd[n_train:n_train + n_val])
                    self.idx_test = np.sort(rnd[n_train + n_val:])
                elif 'papers' in self.name:
                    # Common
                    n_train = NTRAIN_PER_CLASS * self.nclass
                    n_val = int(1.5 * NTRAIN_PER_CLASS * self.nclass)
                    self.input(['idx_train', 'idx_val', 'idx_test'])
                    rnd = np.concatenate((self.idx_train, self.idx_val, self.idx_test))
                    idxrange = n_train + n_val + 2000
                    rnd = np.random.permutation(rnd)[:idxrange]
                    idx_train, idx_val, idx_test = split_label(self.seed, len(rnd), NTRAIN_PER_CLASS, n_val, self.labels[rnd])
                    # NIGCN
                    # self.input(['idx_train', 'idx_val', 'idx_test'])
                    # rnd = np.concatenate((self.idx_train, self.idx_val, self.idx_test))
                    # n_train, n_val = 1000, 25000
                    # idxrange = n_train + n_val + 25000
                    # idx_train, idx_val, idx_test = split_random(self.seed, idxrange, n_train, n_val)

                    self.idx_train = np.sort(rnd[idx_train])
                    self.idx_val = np.sort(rnd[idx_val])
                    self.idx_test = np.sort(rnd[idx_test])
                elif 'mag' in self.name:
                    # self.idx_train, self.idx_val, self.idx_test = split_label(self.seed, self.n, NTRAIN_PER_CLASS * 5, n_val, self.labels)
                    self.idx_train, self.idx_val, self.idx_test = split_stratify(self.seed, self.n, n_train * 5, n_val, self.labels)
                elif 'ppi' in self.name or 'protein' in self.name or 'yelp' in self.name or 'amazon' in self.name:
                    self.idx_train, self.idx_val, self.idx_test = split_random(self.seed, self.n, n_train, n_val)
                else:
                    # self.idx_train, self.idx_val, self.idx_test = split_random(self.seed, self.n, n_train, n_val)
                    # self.idx_train, self.idx_val, self.idx_test = split_label(self.seed, self.n, NTRAIN_PER_CLASS, n_val, self.labels)
                    self.idx_train, self.idx_val, self.idx_test = split_stratify(self.seed, self.n, n_train, n_val, self.labels)
            elif key == 'labels_oh':
                if self.labels.ndim == 2:
                    self.labels_oh = self.labels
                else:
                    self.labels_oh = np.zeros((self.n, self.nclass), dtype=np.int8)
                    idx = ~ np.isnan(self.labels)
                    row = np.arange(self.labels.size)
                    self.labels_oh[row[idx], self.labels[idx]] = 1
            elif key == 'role':
                self.role = {}
                self.role['tr'] = self.idx_train.tolist()
                self.role['va'] = self.idx_val.tolist()
                self.role['te'] = self.idx_test.tolist()
            elif key == 'mask':
                self.mask = {}
                self.mask['tr'] = np.zeros(self.n, dtype=bool)
                self.mask['va'] = np.zeros(self.n, dtype=bool)
                self.mask['te'] = np.zeros(self.n, dtype=bool)
                self.mask['tr'][self.idx_train] = True
                self.mask['va'][self.idx_val] = True
                self.mask['te'][self.idx_test] = True
            elif key == 'edge_idx':
                self.edge_idx = self.adj_matrix.tocoo().copy()
                self.edge_idx = np.vstack([self.edge_idx.row, self.edge_idx.col])
            elif key == 'attr_matrix_norm':
                assert self.attr_matrix is not None
                assert self.deg is not None
                deg_pow = np.power(np.maximum(self.deg, 1e-12), 1 - self.rrz)
                deg_pow = diag_sp(deg_pow).astype(np.float32)
                self.attr_matrix_norm = deg_pow @ matstd(self.attr_matrix)
                self.attr_matrix_norm = matnorm_inf_dual(self.attr_matrix_norm).astype(np.float32)
                self.attr_matrix_norm = self.attr_matrix_norm.transpose().astype(np.float32, order='C')
            else:
                print("Key not exist: {}".format(key))

    def input(self, lst: List[str]) -> None:
        for key in lst:
            if key == 'adjnpz':
                self.adj_matrix = sp.load_npz(self.adjnpz_path)
                # assert self.adj_matrix.diagonal().sum() == 0, "adj_matrix error"
            elif key == 'adjtxt':
                with open(self.adjtxt_path, 'r') as attr_f:
                    nline = attr_f.readline().rstrip()
                self._n = int(''.join(filter(str.isdigit, nline)))
                adjtxt = np.loadtxt(self.adjtxt_path)
                self._m = adjtxt.shape[0]
                ones = np.ones((self.m), dtype=np.int8)
                self.adj_matrix = sp.coo_matrix(
                    (ones, (adjtxt[:, 0], adjtxt[:, 1])),
                    shape=(self.n, self.n))
                self.adj_matrix = self.adj_matrix.tocsr()
                # assert self.adj_matrix.diagonal().sum() == 0, "adj_matrix error"
            elif key == 'deg':
                self.deg = dict(np.load(self.degree_path))['arr_0']
            elif key == 'labels':
                self.labels = dict(np.load(self.labels_path, allow_pickle=True))['labels']
                # assert (self.labels.dim()==2 and self.labels.shape[1]==1) or self.labels.dim()==1, "label shape error"
            elif key == 'idx_train':
                self.idx_train = dict(np.load(self.labels_path, allow_pickle=True))['idx_train']
            elif key == 'idx_val':
                self.idx_val = dict(np.load(self.labels_path, allow_pickle=True))['idx_val']
            elif key == 'idx_test':
                self.idx_test = dict(np.load(self.labels_path, allow_pickle=True))['idx_test']
            elif key == 'attr_matrix':
                self.attr_matrix = np.load(self.feats_path)
            elif key == 'attr_matrix_norm':
                self.attr_matrix_norm = np.load(self.featsnorm_path)
            else:
                print("Key not exist: {}".format(key))

    def output(self, lst: List[str]) -> None:
        for key in lst:
            if key == 'adjnpz':
                self.adj_matrix = self.adj_matrix.tocsr()
                assert sp.isspmatrix_csr(self.adj_matrix)
                sp.save_npz(self.adjnpz_path, self.adj_matrix)
            elif key == 'adjtxt':
                self.adj_matrix = self.adj_matrix.tocoo()
                with open(self.adjtxt_path, 'w') as f:
                    f.write("# {:d}\n".format(self.n))
                    for i in range(self.m):
                        f.write("{:d} {:d}\n".format(self.adj_matrix.row[i], self.adj_matrix.col[i]))
            elif key == 'adjl':
                import struct
                self.adj_matrix = self.adj_matrix.tocsr()
                assert sp.isspmatrix_csr(self.adj_matrix), "Adj wrong format"
                el = self.adj_matrix.indices
                pl = self.adj_matrix.indptr
                el = np.array(el, dtype=np.uint32)
                pl = np.array(pl, dtype=np.uint32)

                el_re = []
                for i in range(1,pl.shape[0]):
                    el_re += sorted(el[pl[i-1]:pl[i]],key=lambda x:pl[x+1]-pl[x])
                el = np.asarray(el_re,dtype=np.uint32)

                with open(self._get_path('adj_el.bin'), 'wb') as f:
                    for i in el:
                        m = struct.pack('I', i)
                        f.write(m)
                with open(self._get_path('adj_pl.bin'), 'wb') as f:
                    for i in pl:
                        m = struct.pack('I', i)
                        f.write(m)
            elif key == 'attribute':
                with open(self._get_path("attribute.txt"), 'w') as f:
                    f.write(f"n={self.n:d}\n")
                    f.write(f"m={self.m:d}")
            elif key == 'deg':
                np.savez_compressed(self.degree_path, self.deg)
            elif key in ['labels', 'idx_train', 'idx_val', 'idx_test']:
                labels_dict = {'labels': self.labels,
                               'idx_train': self.idx_train,
                               'idx_val': self.idx_val,
                               'idx_test': self.idx_test}
                np.savez_compressed(self.labels_path, **labels_dict)
            elif key == 'query':
                query = np.arange(self.n, dtype=int)
                np.savetxt(self.query_path, query, fmt='%d', delimiter='\n')
            elif key == 'query_topdeg':
                k = self.nfeat
                idx = np.argpartition(self.deg, -k)[-k:]
                np.savetxt(self.query_path, idx, fmt='%d', delimiter='\n')
            elif key == 'query_train':
                assert self.idx_train is not None
                np.savetxt(self.querytrain_path, self.idx_train, fmt='%d', delimiter='\n')
            elif key == 'attr_matrix':
                self.attr_matrix = self.attr_matrix.astype(np.float32, order='C')
                np.save(self.feats_path, self.attr_matrix)
            elif key == 'attr_matrix_norm':
                self.attr_matrix_norm = self.attr_matrix_norm.astype(np.float32, order='C')
                np.save(self.featsnorm_path, self.attr_matrix_norm)
            else:
                print("Key not exist: {}".format(key))

    def output_split(self, attr_matrix: Optional[np.ndarray], spt: int=10, name: str='feats') -> None:
        """Split large matrix by feature dimension."""
        from tqdm import trange
        if attr_matrix is None:
            attr_matrix = self.attr_matrix
        n = attr_matrix.shape[0]
        nd = n // spt
        for i in trange(spt):
            if i < spt - 1:
                idxl, idxr = i * nd, (i+1) * nd
            else:
                idxl, idxr = i * nd, n
            prt = attr_matrix[idxl:idxr, :]

            prt_path = self._get_path('{}_{}.npy'.format(name, i))
            np.save(prt_path, prt)

    def to_undirected(self) -> None:
        self.adj_matrix = self.adj_matrix + self.adj_matrix.T
        self.adj_matrix.data = np.ones(len(self.adj_matrix.data), dtype=np.int8)
        self._m = self.adj_matrix.nnz

        self.calculate(['deg'])
        idx_zero = np.where(self.deg == 0)[0]
        if len(idx_zero) > 0:
            print(f"Warning: {len(idx_zero)} isolated nodes found: {idx_zero}!")


class DataProcess_inductive(DataProcess):
    """ Inductive processor for generating adj and attr of only train nodes
    For graphs with edge attributes refer to pyg.utils.subgraph
    """
    def  __init__(self, name: str, path: str = '../data/', rrz: float = 0.5, seed: int = 0) -> None:
        name = name + '_train'
        super().__init__(name, path, rrz, seed)

    def fetch(self) -> None:
        # Node index mapping
        assert self.adj_matrix is not None
        assert self.idx_train is not None
        nraw = self.adj_matrix.shape[0]
        ntrain = self.n_train
        mapping = - np.ones(nraw, dtype=int)   # key: old index, value: 0~ntrain-1
        mapping[self.idx_train] = np.arange(ntrain)

        # Construct induced adj
        self.adj_matrix = self.adj_matrix.tocoo()
        idx_in = np.isin(self.adj_matrix.col, self.idx_train) & np.isin(self.adj_matrix.row, self.idx_train)
        col, row = mapping[self.adj_matrix.col[idx_in]], mapping[self.adj_matrix.row[idx_in]]
        ones = np.ones(len(col), dtype=np.int8)
        self.adj_matrix = sp.coo_matrix(
            (ones, (col, row)),
            shape=(ntrain, ntrain))

        self.adj_matrix = self.adj_matrix.tocsr()
        self.adj_matrix.setdiag(0)
        self.adj_matrix.eliminate_zeros()
        self.adj_matrix.data = np.ones(len(self.adj_matrix.data), dtype=np.int8)
        self._n, self._m = ntrain, self.adj_matrix.nnz

        # Construct induced attr
        assert self.attr_matrix is not None
        self.attr_matrix = self.attr_matrix[self.idx_train]
        self.attr_matrix = self.attr_matrix.astype(np.float32, order='C')


# if __name__ == '__main__':
    # dp = DataProcess('pubmed', seed=0)
    # dp.input(['adjtxt', 'attr_matrix', 'labels'])
    # dp.calculate(['deg', 'idx_train'])
    # dp.output(['deg', 'query'])
    # print(dp)

# %%
# -*- coding:utf-8 -*-
""" Convert OGB data
Author: nyLiao
File Created: 2021-12-01
"""
import os
import json
import numpy as np
import torch_geometric.datasets as pyg_ds
import torch_geometric.transforms as pyg_t
import torch_geometric.utils as pyg_utils
from ogb.nodeproppred import NodePropPredDataset

# from data_processor import *


class DataProcess_OGB(DataProcess):
    def __init__(self, name, path='../data/', rrz=0.5, seed=0) -> None:
        super().__init__(name, path=path, rrz=rrz, seed=seed)

    @property
    def n_train(self):
        if self.idx_train is None:
            self.input(['labels'])
        return len(self.idx_train)

    def fetch(self):
        dataset = NodePropPredDataset(name=self.name, root='/share/data/dataset/OGB')
        split_idx = dataset.get_idx_split()
        idx_train, idx_val, idx_test = split_idx["train"], split_idx["valid"], split_idx["test"]
        graph, labels = dataset[0]

        row, col = graph['edge_index'][0], graph['edge_index'][1]
        row, col = np.concatenate([row, col], axis=0), np.concatenate([col, row], axis=0)
        deg = np.bincount(row)
        idx_zero = np.where(deg == 0)[0]
        if len(idx_zero) > 0:
            print(f"Warning: removing {len(idx_zero)} isolated nodes: {idx_zero}!")

        # remove isolated nodes
        nodelst = deg.nonzero()[0]
        idxnew = np.full(graph['num_nodes'], -1)
        idxnew[nodelst] = np.arange(len(nodelst))
        self._n = len(nodelst)
        row, col = idxnew[row], idxnew[col]
        self.adj_matrix = edgeidx2adj(row, col, self.n)
        self._m = self.adj_matrix.nnz

        self.attr_matrix = graph['node_feat'][nodelst]
        assert (labels.ndim==2 and labels.shape[1]==1) or labels.ndim==1, "label shape error"
        self.labels = labels.flatten()[nodelst]

        self.idx_train = idxnew[idx_train]
        self.idx_train = self.idx_train[self.idx_train > -1]
        self.idx_val = idxnew[idx_val]
        self.idx_val = self.idx_val[self.idx_val > -1]
        self.idx_test = idxnew[idx_test]
        self.idx_test = self.idx_test[self.idx_test > -1]


class DataProcess_PyGFlickr(DataProcess):
    def __init__(self, name, path='../data/', rrz=0.5, seed=0) -> None:
        super().__init__(name, path=path, rrz=rrz, seed=seed)

    def fetch(self):
        # dataset = pyg_ds.Flickr(root='/share/data/dataset/PyG/Flickr', transform=pyg_t.ToUndirected())
        # graph = dataset[0]

        root = '/share/data/dataset/PyG/Flickr/raw'
        f = np.load(os.path.join(root, 'adj_full.npz'))
        self.adj_matrix = sp.csr_matrix((f['data'], f['indices'], f['indptr']), f['shape'])
        self.to_undirected()
        self.attr_matrix = np.load(os.path.join(root, 'feats.npy'), allow_pickle=True)

        ys = [-1] * self.attr_matrix.shape[0]
        with open(os.path.join(root, 'class_map.json')) as f:
            class_map = json.load(f)
            for key, item in class_map.items():
                ys[int(key)] = item
        self.labels = np.array(ys).flatten()
        if self.labels.min() < 0:
            print(f"Warning: negative label: {self.labels.min()}")

        with open(os.path.join(root, 'role.json')) as f:
            role = json.load(f)
        self.idx_train = np.array(role['tr'])
        self.idx_val = np.array(role['va'])
        self.idx_test = np.array(role['te'])


class DataProcess_PyG(DataProcess):
    def __init__(self, name, path='../data/', rrz=0.5, seed=0) -> None:
        super().__init__(name, path=path, rrz=rrz, seed=seed)

    def fetch(self):
        # dataset = pyg_ds.Coauthor(root='/share/data/dataset/PyG/Coauthor', name='CS', transform=pyg_t.ToUndirected())
        dataset = pyg_ds.Amazon(
            root='./data/raw/Amazon',
            name='Computers',
            transform=pyg_t.ToUndirected()
        )
        graph = dataset[0]
        degree = pyg_utils.degree(graph.edge_index[0], graph.num_nodes)
        idx_zero = np.where(degree == 0)[0]
        if len(idx_zero) > 0:
            print(f"Warning: removing {len(idx_zero)} isolated nodes: {idx_zero}!")

        self._n = graph.num_nodes
        self.adj_matrix = edgeidx2adj(graph.edge_index[0], graph.edge_index[1], self.n)
        self._m = self.adj_matrix.nnz
        self.attr_matrix = graph.x.numpy()
        self.labels = graph.y.numpy().flatten()
        if self.labels.min() < 0:
            print(f"Warning: negative label: {self.labels.min()}")
        n = len(self.labels)
        idx = np.arange(n)
        np.random.seed(self.seed)
        np.random.shuffle(idx)

        train_size = int(0.6 * n)
        val_size = int(0.2 * n)

        self.idx_train = idx[:train_size]
        self.idx_val = idx[train_size:train_size+val_size]
        self.idx_test = idx[train_size+val_size:]

# ====================
if __name__ == '__main__':
    ds = DataProcess_PyG('amazon_computers', path='./data/processed')

    ds.fetch()
    ds.calculate(['deg', 'idx_train'])

    print(ds)

    os.makedirs(os.path.join(ds.path, ds.name), exist_ok=True)

    ds.output([
        'adjtxt',
        'adjnpz',
        'adjl',
        'attr_matrix',
        'deg',
        'labels'
    ])
# Out:
# Warning: removing 281 isolated nodes: [   10    24    43    96   143   230   256   272   342   437   453   464
#    466   492   523   551   556   558   565   643   755   762  1031  1175
#   1188  1211  1258  1317  1468  1509  1538  1550  1611  1666  1745  1758
#   1840  1847  2028  2032  2085  2103  2250  2292  2330  2337  2346  2499
#   2515  2533  2646  2663  2669  2696  2721  2757  2795  2804  2812  2816
#   2860  2882  2883  2904  2993  3043  3240  3356  3458  3485  3555  3562
#   3583  3655  3662  3742  3764  3777  3818  3841  4036  4076  4104  4106
#   4136  4193  4234  4312  4323  4360  4478  4656  4682  4694  4712  4721
#   4744  4791  4853  4866  4871  4911  4970  4992  5105  5111  5116  5148
#   5165  5173  5201  5279  5361  5447  5460  5485  5544  5575  5586  5663
#   5695  5702  5720  5743  5838  5944  5946  5957  5975  6006  6074  6245
#   6273  6476  6599  6685  6699  6707  6797  6842  6863  6982  7100  7113
#   7119  7155  7312  7388  7486  7493  7513  7554  7558  7625  7706  7746
#   7803  7818  7903  7918  8066  8122  8179  8212  8235  8250  8288  8432
#   8455  8475  8485  8488  8537  8557  8569  8591  8645  8652  8703  8730
#   8806  8855  8909  8945  8957  8973  8989  9030  9056  9180  9283  9304
#   9322  9386  9433  9522  9659  9670  9711  9801  9880  9896 10023 10055
#  10141 10148 10190 10219 10252 10283 10330 10337 10384 10411 10412 10430
#  10439 10447 10509 10539 10589 10592 10614 10641 10699 10707 10808 10811
#  10819 10835 10871 10906 11139 11219 11241 11244 11312 11324 11381 11386
#  11388 11394 11406 11440 11469 11508 11511 11614 11651 11663 11695 11769
#  11842 11846 11886 11893 11961 12046 12119 12193 12281 12285 12320 12334
#  12539 12589 12614 12646 12765 12820 12828 12851 13013 13043 13092 13287
#  13360 13391 13478 13639 13645]!
# n=13752, m=491722, F=767, C=10 | feat: (13752, 767), label: (13752,) | 6876/3438/3438=0.50/0.25/0.25

# %%
print("Saving to:", os.path.join(ds.path, ds.name))
print("Exists:", os.path.exists(os.path.join(ds.path, ds.name)))
print("Files:", os.listdir(os.path.join(ds.path, ds.name)))
# Out:
# Saving to: ./data/processed/amazon_computers
# Exists: True
# Files: ['adj_pl.bin', 'adj.txt', 'feats.npy', 'adj.npz', 'adj_el.bin', 'labels.npz', 'degree.npz']

# %% [markdown]
# # Run

# %% [markdown]
# ## Cora

# %%
# !python run_fb.py -f 42 -c config/cora.json -v 0
# Out:
# Option saved.
# Config path: ./save/cora/gcn_thr/42-5.0e-01-5.0e-01/config.json
# Option dict: {'data': 'cora', 'path': './data/', 'algo': 'gcn_thr', 'epochs': 200, 'patience': 20, 'lr': 0.001, 'weight_decay': 1e-05, 'layer': 2, 'hidden': 512, 'dropout': 0.5, 'thr_a': 0.5, 'thr_w': 0.5, 'inductive': False, 'multil': False, 'seed': 42, 'dev': 0, 'config': 'config/cora.json', 'suffix': ''}
#
# n=2485, m=12623, F=1433, C=7 | feat: (2485, 1433), label: (2485,) | 1242/621/622=0.50/0.25/0.25
# GNNThr gcn_thr 0.5 0.5
# GNNThr(
#   (dropout): Dropout(p=0.5, inplace=False)
#   (act): ReLU()
#   (convs): ModuleList(
#     (0): GCNConvThr(1433, 512)
#     (1): GCNConvThr(512, 7)
#   )
#   (norms): ModuleList(
#     (0): BatchNorm1d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   )
# )
# Epoch:0001 | train loss:2.0186, val acc:0.5427, time:0.7922, macs:1.1526
# Epoch:0002 | train loss:1.4088, val acc:0.7488, time:0.8081, macs:2.2890
# Epoch:0003 | train loss:1.0487, val acc:0.8196, time:0.8210, macs:3.4128
# Epoch:0004 | train loss:0.8003, val acc:0.8390, time:0.8344, macs:4.5249
# Epoch:0005 | train loss:0.6295, val acc:0.8470, time:0.8491, macs:5.6261
# Epoch:0006 | train loss:0.5244, val acc:0.8615, time:0.8650, macs:6.7173
# Epoch:0007 | train loss:0.4539, val acc:0.8647, time:0.8874, macs:7.7993
# Epoch:0008 | train loss:0.3907, val acc:0.8647, time:0.9007, macs:8.8726
# Epoch:0009 | train loss:0.3428, val acc:0.8647, time:0.9137, macs:9.9377
# Epoch:0010 | train loss:0.3125, val acc:0.8680, time:0.9265, macs:10.9952
# Epoch:0011 | train loss:0.2946, val acc:0.8631, time:0.9423, macs:12.0458
# Epoch:0012 | train loss:0.2743, val acc:0.8631, time:0.9552, macs:13.0901
# Epoch:0013 | train loss:0.2450, val acc:0.8583, time:0.9680, macs:14.1281
# Epoch:0014 | train loss:0.2237, val acc:0.8599, time:0.9808, macs:15.1603
# Epoch:0015 | train loss:0.2135, val acc:0.8631, time:0.9971, macs:16.1869
# Epoch:0016 | train loss:0.2032, val acc:0.8599, time:1.0108, macs:17.2084
# Epoch:0017 | train loss:0.1938, val acc:0.8615, time:1.0230, macs:18.2250
# Epoch:0018 | train loss:0.1846, val acc:0.8615, time:1.0354, macs:19.2369
# Epoch:0019 | train loss:0.1749, val acc:0.8599, time:1.0479, macs:20.2444
# Epoch:0020 | train loss:0.1661, val acc:0.8631, time:1.0600, macs:21.2479
# Epoch:0021 | train loss:0.1593, val acc:0.8615, time:1.0721, macs:22.2476
# Epoch:0022 | train loss:0.1551, val acc:0.8583, time:1.0852, macs:23.2435
# Epoch:0023 | train loss:0.1495, val acc:0.8599, time:1.0975, macs:24.2360
# Epoch:0024 | train loss:0.1478, val acc:0.8599, time:1.1107, macs:25.2253
# Epoch:0025 | train loss:0.1319, val acc:0.8599, time:1.1277, macs:26.2115
# Epoch:0026 | train loss:0.1326, val acc:0.8599, time:1.1399, macs:27.1947
# Epoch:0027 | train loss:0.1292, val acc:0.8583, time:1.1520, macs:28.1750
# Epoch:0028 | train loss:0.1290, val acc:0.8599, time:1.1641, macs:29.1540
# Epoch:0029 | train loss:0.1235, val acc:0.8599, time:1.1765, macs:30.1317
# Epoch:0030 | train loss:0.1204, val acc:0.8599, time:1.1893, macs:31.1084
# Epoch:0031 | train loss:0.1195, val acc:0.8615, time:1.2027, macs:32.0839
# Epoch:0032 | train loss:0.1189, val acc:0.8599, time:1.2185, macs:33.0582
# Epoch:0033 | train loss:0.1134, val acc:0.8599, time:1.2397, macs:34.0315
# Epoch:0034 | train loss:0.1084, val acc:0.8599, time:1.2671, macs:35.0037
# Epoch:0035 | train loss:0.1120, val acc:0.8599, time:1.2849, macs:35.9747
# Epoch:0036 | train loss:0.1112, val acc:0.8615, time:1.3130, macs:36.9448
# Epoch:0037 | train loss:0.1068, val acc:0.8583, time:1.3339, macs:37.9139
# Epoch:0038 | train loss:0.1099, val acc:0.8599, time:1.3483, macs:38.8821
# Epoch:0039 | train loss:0.1074, val acc:0.8583, time:1.3602, macs:39.8494
# Epoch:0040 | train loss:0.1042, val acc:0.8583, time:1.3758, macs:40.8158
# Epoch:0041 | train loss:0.0999, val acc:0.8583, time:1.3961, macs:41.7813
# Epoch:0042 | train loss:0.1023, val acc:0.8583, time:1.4170, macs:42.7459
# Epoch:0043 | train loss:0.1001, val acc:0.8583, time:1.4363, macs:43.7096
# Epoch:0044 | train loss:0.1005, val acc:0.8583, time:1.4570, macs:44.6730
# Epoch:0045 | train loss:0.0981, val acc:0.8583, time:1.4823, macs:45.6359
# Epoch:0046 | train loss:0.0956, val acc:0.8583, time:1.5071, macs:46.5983
# Epoch:0047 | train loss:0.0948, val acc:0.8583, time:1.5278, macs:47.5605
# Epoch:0048 | train loss:0.0972, val acc:0.8583, time:1.5399, macs:48.5222
# Epoch:0049 | train loss:0.0943, val acc:0.8583, time:1.5607, macs:49.4834
# Epoch:0050 | train loss:0.0947, val acc:0.8583, time:1.5731, macs:50.4444
# Epoch:0051 | train loss:0.0915, val acc:0.8599, time:1.5848, macs:51.4049
# Epoch:0052 | train loss:0.0943, val acc:0.8599, time:1.6083, macs:52.3650
# Epoch:0053 | train loss:0.0904, val acc:0.8615, time:1.6313, macs:53.3248
# Epoch:0054 | train loss:0.0952, val acc:0.8615, time:1.6514, macs:54.2842
# Epoch:0055 | train loss:0.0902, val acc:0.8615, time:1.6717, macs:55.2433
# Epoch:0056 | train loss:0.0899, val acc:0.8615, time:1.6891, macs:56.2020
# Epoch:0057 | train loss:0.0935, val acc:0.8615, time:1.7095, macs:57.1603
# Epoch:0058 | train loss:0.0890, val acc:0.8615, time:1.7272, macs:58.1182
# Epoch:0059 | train loss:0.0896, val acc:0.8615, time:1.7503, macs:59.0758
# Epoch:0060 | train loss:0.0892, val acc:0.8615, time:1.7740, macs:60.0333
# Epoch:0061 | train loss:0.0904, val acc:0.8615, time:1.7974, macs:60.9905
# Epoch:0062 | train loss:0.0885, val acc:0.8615, time:1.8159, macs:61.9475
# Epoch:0063 | train loss:0.0874, val acc:0.8615, time:1.8357, macs:62.9044
# Epoch:0064 | train loss:0.0860, val acc:0.8615, time:1.8469, macs:63.8611
# Epoch:0065 | train loss:0.0881, val acc:0.8615, time:1.8668, macs:64.8177
# Epoch:0066 | train loss:0.0838, val acc:0.8615, time:1.8884, macs:65.7740
# Epoch:0067 | train loss:0.0886, val acc:0.8615, time:1.9081, macs:66.7302
# Epoch:0068 | train loss:0.0881, val acc:0.8615, time:1.9322, macs:67.6861
# Epoch:0069 | train loss:0.0864, val acc:0.8615, time:1.9536, macs:68.6419
# Epoch:0070 | train loss:0.0881, val acc:0.8615, time:1.9950, macs:69.5976
# Epoch:0071 | train loss:0.0858, val acc:0.8599, time:2.0209, macs:70.5530
# Epoch:0072 | train loss:0.0855, val acc:0.8599, time:2.0463, macs:71.5082
# Epoch:0073 | train loss:0.0854, val acc:0.8599, time:2.0646, macs:72.4633
# Epoch:0074 | train loss:0.0858, val acc:0.8599, time:2.0899, macs:73.4181
# Epoch:0075 | train loss:0.0842, val acc:0.8599, time:2.1129, macs:74.3728
# Epoch:0076 | train loss:0.0842, val acc:0.8599, time:2.1344, macs:75.3274
# Epoch:0077 | train loss:0.0865, val acc:0.8599, time:2.1572, macs:76.2818
# Epoch:0078 | train loss:0.0848, val acc:0.8599, time:2.1883, macs:77.2362
# Epoch:0079 | train loss:0.0857, val acc:0.8599, time:2.2129, macs:78.1905
# Epoch:0080 | train loss:0.0826, val acc:0.8599, time:2.2377, macs:79.1447
# Epoch:0081 | train loss:0.0822, val acc:0.8599, time:2.2637, macs:80.0988
# Epoch:0082 | train loss:0.0824, val acc:0.8599, time:2.2879, macs:81.0528
# Epoch:0083 | train loss:0.0829, val acc:0.8599, time:2.3138, macs:82.0068
# Epoch:0084 | train loss:0.0832, val acc:0.8583, time:2.3418, macs:82.9607
# Epoch:0085 | train loss:0.0863, val acc:0.8567, time:2.3643, macs:83.9144
# Epoch:0086 | train loss:0.0862, val acc:0.8567, time:2.3908, macs:84.8681
# Epoch:0087 | train loss:0.0826, val acc:0.8567, time:2.4127, macs:85.8217
# Epoch:0088 | train loss:0.0828, val acc:0.8583, time:2.4379, macs:86.7752
# Epoch:0089 | train loss:0.0832, val acc:0.8583, time:2.4618, macs:87.7287
# Epoch:0090 | train loss:0.0826, val acc:0.8599, time:2.4998, macs:88.6820
# Epoch:0091 | train loss:0.0851, val acc:0.8583, time:2.5273, macs:89.6353
# Epoch:0092 | train loss:0.0821, val acc:0.8583, time:2.5532, macs:90.5885
# Epoch:0093 | train loss:0.0849, val acc:0.8583, time:2.5676, macs:91.5418
# Epoch:0094 | train loss:0.0845, val acc:0.8583, time:2.5937, macs:92.4949
# Epoch:0095 | train loss:0.0836, val acc:0.8583, time:2.6159, macs:93.4480
# Epoch:0096 | train loss:0.0849, val acc:0.8583, time:2.6349, macs:94.4011
# Epoch:0097 | train loss:0.0791, val acc:0.8583, time:2.6571, macs:95.3542
# Epoch:0098 | train loss:0.0789, val acc:0.8583, time:2.6789, macs:96.3071
# Epoch:0099 | train loss:0.0858, val acc:0.8583, time:2.6992, macs:97.2601
# Epoch:0100 | train loss:0.0847, val acc:0.8583, time:2.7103, macs:98.2130
# Epoch:0101 | train loss:0.0860, val acc:0.8583, time:2.7429, macs:99.1658
# Epoch:0102 | train loss:0.0836, val acc:0.8583, time:2.7556, macs:100.1187
# Epoch:0103 | train loss:0.0885, val acc:0.8583, time:2.7663, macs:101.0714
# Epoch:0104 | train loss:0.0847, val acc:0.8583, time:2.7794, macs:102.0242
# Epoch:0105 | train loss:0.0833, val acc:0.8583, time:2.7948, macs:102.9768
# Epoch:0106 | train loss:0.0838, val acc:0.8583, time:2.8093, macs:103.9295
# Epoch:0107 | train loss:0.0826, val acc:0.8583, time:2.8241, macs:104.8821
# Epoch:0108 | train loss:0.0792, val acc:0.8599, time:2.8404, macs:105.8346
# Epoch:0109 | train loss:0.0806, val acc:0.8599, time:2.8552, macs:106.7872
# Epoch:0110 | train loss:0.0800, val acc:0.8599, time:2.8684, macs:107.7397
# Epoch:0111 | train loss:0.0822, val acc:0.8599, time:2.8807, macs:108.6922
# Epoch:0112 | train loss:0.0803, val acc:0.8599, time:2.8944, macs:109.6448
# Epoch:0113 | train loss:0.0827, val acc:0.8583, time:2.9085, macs:110.5973
# Epoch:0114 | train loss:0.0816, val acc:0.8583, time:2.9215, macs:111.5497
# Epoch:0115 | train loss:0.0814, val acc:0.8583, time:2.9337, macs:112.5021
# Epoch:0116 | train loss:0.0823, val acc:0.8583, time:2.9674, macs:113.4545
# Epoch:0117 | train loss:0.0826, val acc:0.8583, time:2.9804, macs:114.4068
# Epoch:0118 | train loss:0.0843, val acc:0.8583, time:2.9935, macs:115.3592
# Epoch:0119 | train loss:0.0805, val acc:0.8583, time:3.0070, macs:116.3115
# Epoch:0120 | train loss:0.0822, val acc:0.8583, time:3.0205, macs:117.2638
# Epoch:0121 | train loss:0.0810, val acc:0.8583, time:3.0327, macs:118.2161
# Epoch:0122 | train loss:0.0803, val acc:0.8583, time:3.0475, macs:119.1683
# Epoch:0123 | train loss:0.0828, val acc:0.8583, time:3.0610, macs:120.1206
# Epoch:0124 | train loss:0.0802, val acc:0.8583, time:3.0739, macs:121.0728
# Epoch:0125 | train loss:0.0845, val acc:0.8583, time:3.0864, macs:122.0249
# Epoch:0126 | train loss:0.0827, val acc:0.8583, time:3.1003, macs:122.9771
# Epoch:0127 | train loss:0.0782, val acc:0.8583, time:3.1133, macs:123.9292
# Epoch:0128 | train loss:0.0820, val acc:0.8583, time:3.1279, macs:124.8814
# Epoch:0129 | train loss:0.0801, val acc:0.8583, time:3.1402, macs:125.8336
# Epoch:0130 | train loss:0.0828, val acc:0.8583, time:3.1533, macs:126.7857
# Epoch:0131 | train loss:0.0838, val acc:0.8583, time:3.1657, macs:127.7378
# Epoch:0132 | train loss:0.0834, val acc:0.8583, time:3.1786, macs:128.6899
# Epoch:0133 | train loss:0.0819, val acc:0.8583, time:3.1908, macs:129.6419
# Epoch:0134 | train loss:0.0814, val acc:0.8583, time:3.2041, macs:130.5940
# Epoch:0135 | train loss:0.0804, val acc:0.8583, time:3.2163, macs:131.5461
# Epoch:0136 | train loss:0.0824, val acc:0.8583, time:3.2300, macs:132.4981
# Epoch:0137 | train loss:0.0819, val acc:0.8583, time:3.2426, macs:133.4501
# Epoch:0138 | train loss:0.0813, val acc:0.8583, time:3.2661, macs:134.4021
# Epoch:0139 | train loss:0.0827, val acc:0.8583, time:3.2783, macs:135.3541
# Epoch:0140 | train loss:0.0812, val acc:0.8583, time:3.2924, macs:136.3060
# Epoch:0141 | train loss:0.0784, val acc:0.8583, time:3.3168, macs:137.2580
# Epoch:0142 | train loss:0.0815, val acc:0.8583, time:3.3301, macs:138.2100
# Epoch:0143 | train loss:0.0829, val acc:0.8583, time:3.3419, macs:139.1619
# Epoch:0144 | train loss:0.0784, val acc:0.8583, time:3.3543, macs:140.1139
# Epoch:0145 | train loss:0.0815, val acc:0.8583, time:3.3664, macs:141.0658
# Epoch:0146 | train loss:0.0794, val acc:0.8583, time:3.3797, macs:142.0178
# Epoch:0147 | train loss:0.0803, val acc:0.8583, time:3.3958, macs:142.9697
# Epoch:0148 | train loss:0.0832, val acc:0.8583, time:3.4096, macs:143.9216
# Epoch:0149 | train loss:0.0824, val acc:0.8583, time:3.4222, macs:144.8736
# Epoch:0150 | train loss:0.0799, val acc:0.8583, time:3.4355, macs:145.8255
# Epoch:0151 | train loss:0.0849, val acc:0.8583, time:3.4489, macs:146.7774
# Epoch:0152 | train loss:0.0794, val acc:0.8583, time:3.4634, macs:147.7293
# Epoch:0153 | train loss:0.0817, val acc:0.8583, time:3.4757, macs:148.6812
# Epoch:0154 | train loss:0.0791, val acc:0.8583, time:3.4890, macs:149.6331
# Epoch:0155 | train loss:0.0823, val acc:0.8583, time:3.5028, macs:150.5850
# Epoch:0156 | train loss:0.0831, val acc:0.8583, time:3.5162, macs:151.5369
# Epoch:0157 | train loss:0.0803, val acc:0.8583, time:3.5296, macs:152.4888
# Epoch:0158 | train loss:0.0820, val acc:0.8583, time:3.5441, macs:153.4406
# Epoch:0159 | train loss:0.0829, val acc:0.8583, time:3.5610, macs:154.3925
# Epoch:0160 | train loss:0.0811, val acc:0.8583, time:3.5741, macs:155.3444
# Epoch:0161 | train loss:0.0778, val acc:0.8583, time:3.5876, macs:156.2963
# Epoch:0162 | train loss:0.0797, val acc:0.8583, time:3.6035, macs:157.2482
# Epoch:0163 | train loss:0.0778, val acc:0.8583, time:3.6173, macs:158.2000
# Epoch:0164 | train loss:0.0830, val acc:0.8583, time:3.6317, macs:159.1519
# Epoch:0165 | train loss:0.0806, val acc:0.8583, time:3.6537, macs:160.1037
# Epoch:0166 | train loss:0.0798, val acc:0.8583, time:3.6672, macs:161.0556
# Epoch:0167 | train loss:0.0808, val acc:0.8583, time:3.6827, macs:162.0075
# Epoch:0168 | train loss:0.0830, val acc:0.8583, time:3.6964, macs:162.9593
# Epoch:0169 | train loss:0.0795, val acc:0.8583, time:3.7109, macs:163.9112
# Epoch:0170 | train loss:0.0795, val acc:0.8583, time:3.7262, macs:164.8631
# Epoch:0171 | train loss:0.0792, val acc:0.8583, time:3.7399, macs:165.8149
# Epoch:0172 | train loss:0.0793, val acc:0.8583, time:3.7536, macs:166.7667
# Epoch:0173 | train loss:0.0848, val acc:0.8583, time:3.7813, macs:167.7186
# Epoch:0174 | train loss:0.0849, val acc:0.8583, time:3.7948, macs:168.6704
# Epoch:0175 | train loss:0.0815, val acc:0.8583, time:3.8090, macs:169.6222
# Epoch:0176 | train loss:0.0789, val acc:0.8583, time:3.8235, macs:170.5741
# Epoch:0177 | train loss:0.0817, val acc:0.8583, time:3.8370, macs:171.5259
# Epoch:0178 | train loss:0.0795, val acc:0.8583, time:3.8525, macs:172.4777
# Epoch:0179 | train loss:0.0831, val acc:0.8583, time:3.8661, macs:173.4296
# Epoch:0180 | train loss:0.0795, val acc:0.8583, time:3.8810, macs:174.3814
# Epoch:0181 | train loss:0.0833, val acc:0.8583, time:3.8946, macs:175.3332
# Epoch:0182 | train loss:0.0796, val acc:0.8583, time:3.9087, macs:176.2851
# Epoch:0183 | train loss:0.0822, val acc:0.8583, time:3.9229, macs:177.2369
# Epoch:0184 | train loss:0.0811, val acc:0.8583, time:3.9395, macs:178.1887
# Epoch:0185 | train loss:0.0811, val acc:0.8583, time:3.9527, macs:179.1406
# Epoch:0186 | train loss:0.0806, val acc:0.8583, time:3.9674, macs:180.0924
# Epoch:0187 | train loss:0.0851, val acc:0.8583, time:3.9887, macs:181.0443
# Epoch:0188 | train loss:0.0761, val acc:0.8583, time:4.0030, macs:181.9961
# Epoch:0189 | train loss:0.0823, val acc:0.8583, time:4.0165, macs:182.9479
# Epoch:0190 | train loss:0.0785, val acc:0.8583, time:4.0305, macs:183.8997
# Epoch:0191 | train loss:0.0778, val acc:0.8583, time:4.0435, macs:184.8516
# Epoch:0192 | train loss:0.0830, val acc:0.8583, time:4.0568, macs:185.8034
# Epoch:0193 | train loss:0.0814, val acc:0.8583, time:4.0690, macs:186.7553
# Epoch:0194 | train loss:0.0804, val acc:0.8583, time:4.0824, macs:187.7071
# Epoch:0195 | train loss:0.0832, val acc:0.8583, time:4.0945, macs:188.6589
# Epoch:0196 | train loss:0.0795, val acc:0.8583, time:4.1080, macs:189.6107
# Epoch:0197 | train loss:0.0809, val acc:0.8583, time:4.1216, macs:190.5626
# Epoch:0198 | train loss:0.0843, val acc:0.8583, time:4.1351, macs:191.5144
# Epoch:0199 | train loss:0.0810, val acc:0.8583, time:4.1472, macs:192.4662
# Epoch:0200 | train loss:0.0823, val acc:0.8583, time:4.1602, macs:193.4180
# [Val] best acc: 0.86795 (epoch: 9/200), [Test] best acc: 0.87942
# [Train] time: 4.1602 s (avg: 20.8 ms), MACs: 193.418 G (avg: 1.0 G)
# [Test]  time: 0.0071 s, MACs: 1.0577 G, Num adj: 19.749 k, Num weight: 417.621 k
#       Data|     Model|  Seed|     ThA|     ThW|    Acc|  Cn|  EP|  Ttrain|  Ctrain|   Ttest|   CTest|  NumelA|  NumelW
# cora      ,gcn_thr   ,    42,5.00e-01,5.00e-01,0.87942,   9, 200,  4.1602, 193.418,  0.0071,  1.0577,  19.749, 417.621

# %%
# !python run_fb.py -f 42 -c config/cora_lp.json -v 0
# Out:
# Option saved.
# Config path: ./save/cora/gcn_thr/42-5.0e-01-5.0e-01/config.json
# Option dict: {'data': 'cora', 'path': './data/', 'algo': 'gcn_thr', 'epochs': 500, 'patience': 50, 'lr': 0.001, 'weight_decay': 1e-05, 'layer': 3, 'hidden': 256, 'dropout': 0.8, 'thr_a': 0.5, 'thr_w': 0.5, 'inductive': False, 'multil': False, 'seed': 42, 'dev': 0, 'config': 'config/cora_lp.json', 'suffix': ''}
#
# n=2485, m=12623, F=1433, C=7 | feat: (2485, 1433), label: (2485,) | 1242/621/622=0.50/0.25/0.25
# GNNThr gcn_thr 0.5 0.5
# GNNThr(
#   (dropout): Dropout(p=0.8, inplace=False)
#   (act): ReLU()
#   (convs): ModuleList(
#     (0): GCNConvThr(1433, 256)
#     (1): GCNConvThr(256, 256)
#     (2): GCNConvThr(256, 7)
#   )
#   (norms): ModuleList(
#     (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   )
# )
# Epoch:0001 | train loss:2.4109, val acc:0.1836, time:1.3477, macs:0.7256
# Epoch:0002 | train loss:2.2418, val acc:0.4235, time:1.3856, macs:1.4429
# Epoch:0003 | train loss:2.0838, val acc:0.5684, time:1.4171, macs:2.1556
# Epoch:0004 | train loss:1.8980, val acc:0.6715, time:1.4501, macs:2.8643
# Epoch:0005 | train loss:1.7685, val acc:0.7069, time:1.4638, macs:3.5697
# Epoch:0006 | train loss:1.6920, val acc:0.7375, time:1.4786, macs:4.2720
# Epoch:0007 | train loss:1.5823, val acc:0.7617, time:1.5132, macs:4.9711
# Epoch:0008 | train loss:1.3829, val acc:0.7729, time:1.5451, macs:5.6675
# Epoch:0009 | train loss:1.3858, val acc:0.7939, time:1.5606, macs:6.3612
# Epoch:0010 | train loss:1.3157, val acc:0.8003, time:1.5919, macs:7.0523
# Epoch:0011 | train loss:1.2218, val acc:0.8052, time:1.6169, macs:7.7410
# Epoch:0012 | train loss:1.1987, val acc:0.8164, time:1.6438, macs:8.4273
# Epoch:0013 | train loss:1.1263, val acc:0.8164, time:1.6687, macs:9.1112
# Epoch:0014 | train loss:1.0463, val acc:0.8261, time:1.6973, macs:9.7931
# Epoch:0015 | train loss:1.0377, val acc:0.8293, time:1.7230, macs:10.4726
# Epoch:0016 | train loss:0.9812, val acc:0.8293, time:1.7505, macs:11.1500
# Epoch:0017 | train loss:0.9572, val acc:0.8309, time:1.7773, macs:11.8254
# Epoch:0018 | train loss:0.9040, val acc:0.8309, time:1.7927, macs:12.4988
# Epoch:0019 | train loss:0.8908, val acc:0.8341, time:1.8129, macs:13.1701
# Epoch:0020 | train loss:0.8317, val acc:0.8406, time:1.8446, macs:13.8398
# Epoch:0021 | train loss:0.8304, val acc:0.8357, time:1.8590, macs:14.5077
# Epoch:0022 | train loss:0.7887, val acc:0.8422, time:1.8779, macs:15.1738
# Epoch:0023 | train loss:0.7608, val acc:0.8438, time:1.8922, macs:15.8384
# Epoch:0024 | train loss:0.7893, val acc:0.8438, time:1.9112, macs:16.5015
# Epoch:0025 | train loss:0.7553, val acc:0.8438, time:1.9410, macs:17.1629
# Epoch:0026 | train loss:0.6864, val acc:0.8422, time:1.9870, macs:17.8228
# Epoch:0027 | train loss:0.6934, val acc:0.8438, time:2.0072, macs:18.4812
# Epoch:0028 | train loss:0.7146, val acc:0.8454, time:2.0336, macs:19.1380
# Epoch:0029 | train loss:0.6734, val acc:0.8470, time:2.0509, macs:19.7935
# Epoch:0030 | train loss:0.6553, val acc:0.8486, time:2.0823, macs:20.4478
# Epoch:0031 | train loss:0.6495, val acc:0.8502, time:2.1021, macs:21.1007
# Epoch:0032 | train loss:0.6390, val acc:0.8519, time:2.1285, macs:21.7523
# Epoch:0033 | train loss:0.6079, val acc:0.8519, time:2.1430, macs:22.4029
# Epoch:0034 | train loss:0.6090, val acc:0.8599, time:2.1672, macs:23.0522
# Epoch:0035 | train loss:0.6095, val acc:0.8567, time:2.1838, macs:23.7005
# Epoch:0036 | train loss:0.5989, val acc:0.8567, time:2.2000, macs:24.3476
# Epoch:0037 | train loss:0.5703, val acc:0.8486, time:2.2165, macs:24.9937
# Epoch:0038 | train loss:0.5541, val acc:0.8551, time:2.2384, macs:25.6386
# Epoch:0039 | train loss:0.5363, val acc:0.8551, time:2.2545, macs:26.2825
# Epoch:0040 | train loss:0.5372, val acc:0.8470, time:2.2705, macs:26.9254
# Epoch:0041 | train loss:0.5339, val acc:0.8599, time:2.2869, macs:27.5672
# Epoch:0042 | train loss:0.5240, val acc:0.8551, time:2.3032, macs:28.2079
# Epoch:0043 | train loss:0.5166, val acc:0.8551, time:2.3194, macs:28.8476
# Epoch:0044 | train loss:0.5047, val acc:0.8519, time:2.3394, macs:29.4861
# Epoch:0045 | train loss:0.5005, val acc:0.8519, time:2.3558, macs:30.1237
# Epoch:0046 | train loss:0.5099, val acc:0.8519, time:2.3718, macs:30.7604
# Epoch:0047 | train loss:0.4855, val acc:0.8535, time:2.3887, macs:31.3961
# Epoch:0048 | train loss:0.5022, val acc:0.8502, time:2.4228, macs:32.0311
# Epoch:0049 | train loss:0.4651, val acc:0.8535, time:2.4384, macs:32.6651
# Epoch:0050 | train loss:0.4708, val acc:0.8519, time:2.4535, macs:33.2984
# Epoch:0051 | train loss:0.4536, val acc:0.8519, time:2.4692, macs:33.9307
# Epoch:0052 | train loss:0.4317, val acc:0.8519, time:2.4854, macs:34.5627
# Epoch:0053 | train loss:0.4559, val acc:0.8519, time:2.5015, macs:35.1944
# Epoch:0054 | train loss:0.4443, val acc:0.8486, time:2.5169, macs:35.8256
# Epoch:0055 | train loss:0.4547, val acc:0.8438, time:2.5333, macs:36.4565
# Epoch:0056 | train loss:0.4266, val acc:0.8519, time:2.5519, macs:37.0869
# Epoch:0057 | train loss:0.4421, val acc:0.8551, time:2.5668, macs:37.7169
# Epoch:0058 | train loss:0.4264, val acc:0.8486, time:2.5823, macs:38.3464
# Epoch:0059 | train loss:0.4201, val acc:0.8519, time:2.5978, macs:38.9757
# Epoch:0060 | train loss:0.4206, val acc:0.8470, time:2.6136, macs:39.6046
# Epoch:0061 | train loss:0.4123, val acc:0.8567, time:2.6292, macs:40.2330
# Epoch:0062 | train loss:0.4110, val acc:0.8519, time:2.6449, macs:40.8612
# Epoch:0063 | train loss:0.4173, val acc:0.8519, time:2.6610, macs:41.4890
# Epoch:0064 | train loss:0.4017, val acc:0.8486, time:2.6769, macs:42.1165
# Epoch:0065 | train loss:0.3858, val acc:0.8519, time:2.6933, macs:42.7436
# Epoch:0066 | train loss:0.4190, val acc:0.8567, time:2.7085, macs:43.3703
# Epoch:0067 | train loss:0.4190, val acc:0.8535, time:2.7242, macs:43.9968
# Epoch:0068 | train loss:0.4161, val acc:0.8502, time:2.7400, macs:44.6232
# Epoch:0069 | train loss:0.4276, val acc:0.8486, time:2.7559, macs:45.2494
# Epoch:0070 | train loss:0.4168, val acc:0.8502, time:2.7726, macs:45.8754
# Epoch:0071 | train loss:0.3994, val acc:0.8519, time:2.7896, macs:46.5013
# Epoch:0072 | train loss:0.4039, val acc:0.8454, time:2.8049, macs:47.1271
# Epoch:0073 | train loss:0.3918, val acc:0.8486, time:2.8213, macs:47.7527
# Epoch:0074 | train loss:0.3947, val acc:0.8502, time:2.8368, macs:48.3780
# Epoch:0075 | train loss:0.3931, val acc:0.8567, time:2.8526, macs:49.0034
# Epoch:0076 | train loss:0.3921, val acc:0.8486, time:2.8684, macs:49.6286
# Epoch:0077 | train loss:0.4033, val acc:0.8454, time:2.8840, macs:50.2536
# Epoch:0078 | train loss:0.3993, val acc:0.8470, time:2.8999, macs:50.8784
# Epoch:0079 | train loss:0.3818, val acc:0.8551, time:2.9156, macs:51.5031
# Epoch:0080 | train loss:0.4001, val acc:0.8535, time:2.9338, macs:52.1277
# Epoch:0081 | train loss:0.4043, val acc:0.8486, time:2.9512, macs:52.7520
# Epoch:0082 | train loss:0.4019, val acc:0.8535, time:2.9682, macs:53.3762
# Epoch:0083 | train loss:0.3681, val acc:0.8502, time:2.9847, macs:54.0004
# Epoch:0084 | train loss:0.4125, val acc:0.8519, time:3.0009, macs:54.6243
# Epoch:0085 | train loss:0.3944, val acc:0.8486, time:3.0172, macs:55.2483
# Epoch:0086 | train loss:0.3976, val acc:0.8502, time:3.0356, macs:55.8721
# Epoch:0087 | train loss:0.3835, val acc:0.8535, time:3.0513, macs:56.4960
# Epoch:0088 | train loss:0.4091, val acc:0.8486, time:3.0678, macs:57.1198
# Epoch:0089 | train loss:0.3776, val acc:0.8502, time:3.0824, macs:57.7435
# Epoch:0090 | train loss:0.3801, val acc:0.8551, time:3.0979, macs:58.3672
# Epoch:0091 | train loss:0.3869, val acc:0.8486, time:3.1148, macs:58.9907
# Epoch:0092 | train loss:0.3934, val acc:0.8519, time:3.1300, macs:59.6142
# Epoch:0093 | train loss:0.3829, val acc:0.8535, time:3.1458, macs:60.2377
# Epoch:0094 | train loss:0.3848, val acc:0.8551, time:3.1617, macs:60.8610
# Epoch:0095 | train loss:0.3806, val acc:0.8519, time:3.1780, macs:61.4842
# Epoch:0096 | train loss:0.3721, val acc:0.8502, time:3.1944, macs:62.1074
# Epoch:0097 | train loss:0.3840, val acc:0.8486, time:3.2105, macs:62.7305
# Epoch:0098 | train loss:0.4055, val acc:0.8519, time:3.2268, macs:63.3535
# Epoch:0099 | train loss:0.3887, val acc:0.8486, time:3.2426, macs:63.9766
# Epoch:0100 | train loss:0.3857, val acc:0.8502, time:3.2577, macs:64.5996
# Epoch:0101 | train loss:0.3818, val acc:0.8551, time:3.2731, macs:65.2225
# Epoch:0102 | train loss:0.3808, val acc:0.8502, time:3.2884, macs:65.8453
# Epoch:0103 | train loss:0.3805, val acc:0.8470, time:3.3048, macs:66.4682
# Epoch:0104 | train loss:0.3929, val acc:0.8519, time:3.3187, macs:67.0911
# Epoch:0105 | train loss:0.3739, val acc:0.8486, time:3.3335, macs:67.7139
# Epoch:0106 | train loss:0.3794, val acc:0.8502, time:3.3488, macs:68.3366
# Epoch:0107 | train loss:0.3687, val acc:0.8486, time:3.3671, macs:68.9594
# Epoch:0108 | train loss:0.3979, val acc:0.8486, time:3.3836, macs:69.5821
# Epoch:0109 | train loss:0.3806, val acc:0.8486, time:3.3999, macs:70.2048
# Epoch:0110 | train loss:0.3929, val acc:0.8470, time:3.4159, macs:70.8275
# Epoch:0111 | train loss:0.3911, val acc:0.8519, time:3.4317, macs:71.4501
# Epoch:0112 | train loss:0.3853, val acc:0.8519, time:3.4480, macs:72.0726
# Epoch:0113 | train loss:0.3898, val acc:0.8502, time:3.4745, macs:72.6950
# Epoch:0114 | train loss:0.3737, val acc:0.8583, time:3.4904, macs:73.3175
# Epoch:0115 | train loss:0.3679, val acc:0.8470, time:3.5061, macs:73.9400
# Epoch:0116 | train loss:0.3731, val acc:0.8519, time:3.5218, macs:74.5625
# Epoch:0117 | train loss:0.3957, val acc:0.8502, time:3.5376, macs:75.1850
# Epoch:0118 | train loss:0.3670, val acc:0.8470, time:3.5536, macs:75.8075
# Epoch:0119 | train loss:0.3871, val acc:0.8486, time:3.5700, macs:76.4298
# Epoch:0120 | train loss:0.3804, val acc:0.8454, time:3.5855, macs:77.0522
# Epoch:0121 | train loss:0.3639, val acc:0.8502, time:3.6013, macs:77.6745
# Epoch:0122 | train loss:0.3710, val acc:0.8535, time:3.6168, macs:78.2968
# Epoch:0123 | train loss:0.3708, val acc:0.8535, time:3.6333, macs:78.9191
# Epoch:0124 | train loss:0.3787, val acc:0.8502, time:3.6493, macs:79.5414
# Epoch:0125 | train loss:0.3687, val acc:0.8438, time:3.6681, macs:80.1637
# Epoch:0126 | train loss:0.3973, val acc:0.8486, time:3.6829, macs:80.7859
# Epoch:0127 | train loss:0.3917, val acc:0.8422, time:3.6990, macs:81.4082
# Epoch:0128 | train loss:0.3849, val acc:0.8486, time:3.7149, macs:82.0304
# Epoch:0129 | train loss:0.3803, val acc:0.8535, time:3.7300, macs:82.6525
# Epoch:0130 | train loss:0.3708, val acc:0.8502, time:3.7461, macs:83.2747
# Epoch:0131 | train loss:0.3523, val acc:0.8535, time:3.7617, macs:83.8970
# Epoch:0132 | train loss:0.3555, val acc:0.8535, time:3.7821, macs:84.5192
# Epoch:0133 | train loss:0.3733, val acc:0.8535, time:3.7979, macs:85.1413
# Epoch:0134 | train loss:0.3773, val acc:0.8486, time:3.8131, macs:85.7635
# Epoch:0135 | train loss:0.3731, val acc:0.8519, time:3.8290, macs:86.3857
# Epoch:0136 | train loss:0.3845, val acc:0.8551, time:3.8455, macs:87.0079
# Epoch:0137 | train loss:0.3710, val acc:0.8551, time:3.8615, macs:87.6299
# Epoch:0138 | train loss:0.3787, val acc:0.8535, time:3.8788, macs:88.2520
# Epoch:0139 | train loss:0.3659, val acc:0.8551, time:3.8949, macs:88.8741
# Epoch:0140 | train loss:0.3956, val acc:0.8454, time:3.9106, macs:89.4962
# Epoch:0141 | train loss:0.3867, val acc:0.8486, time:3.9267, macs:90.1183
# Epoch:0142 | train loss:0.3624, val acc:0.8551, time:3.9434, macs:90.7403
# Epoch:0143 | train loss:0.3668, val acc:0.8502, time:3.9597, macs:91.3624
# Epoch:0144 | train loss:0.3737, val acc:0.8486, time:3.9796, macs:91.9844
# Epoch:0145 | train loss:0.3729, val acc:0.8486, time:3.9956, macs:92.6064
# Epoch:0146 | train loss:0.3684, val acc:0.8519, time:4.0114, macs:93.2285
# Epoch:0147 | train loss:0.3716, val acc:0.8470, time:4.0270, macs:93.8505
# Epoch:0148 | train loss:0.3808, val acc:0.8519, time:4.0433, macs:94.4726
# Epoch:0149 | train loss:0.3741, val acc:0.8502, time:4.0591, macs:95.0945
# Epoch:0150 | train loss:0.3719, val acc:0.8454, time:4.0746, macs:95.7166
# Epoch:0151 | train loss:0.3749, val acc:0.8535, time:4.0908, macs:96.3385
# Epoch:0152 | train loss:0.3766, val acc:0.8502, time:4.1067, macs:96.9604
# Epoch:0153 | train loss:0.3663, val acc:0.8502, time:4.1231, macs:97.5825
# Epoch:0154 | train loss:0.3770, val acc:0.8502, time:4.1397, macs:98.2045
# Epoch:0155 | train loss:0.3943, val acc:0.8535, time:4.1555, macs:98.8264
# Epoch:0156 | train loss:0.3787, val acc:0.8486, time:4.1712, macs:99.4484
# Epoch:0157 | train loss:0.3667, val acc:0.8486, time:4.1869, macs:100.0704
# Epoch:0158 | train loss:0.3660, val acc:0.8486, time:4.2029, macs:100.6923
# Epoch:0159 | train loss:0.3851, val acc:0.8535, time:4.2183, macs:101.3142
# Epoch:0160 | train loss:0.3986, val acc:0.8454, time:4.2340, macs:101.9362
# Epoch:0161 | train loss:0.3955, val acc:0.8502, time:4.2488, macs:102.5583
# Epoch:0162 | train loss:0.3631, val acc:0.8486, time:4.2656, macs:103.1803
# Epoch:0163 | train loss:0.3824, val acc:0.8535, time:4.2810, macs:103.8022
# Epoch:0164 | train loss:0.3710, val acc:0.8502, time:4.2977, macs:104.4241
# Epoch:0165 | train loss:0.3798, val acc:0.8519, time:4.3169, macs:105.0459
# Epoch:0166 | train loss:0.3967, val acc:0.8470, time:4.3330, macs:105.6679
# Epoch:0167 | train loss:0.3765, val acc:0.8535, time:4.3496, macs:106.2899
# Epoch:0168 | train loss:0.3798, val acc:0.8486, time:4.3657, macs:106.9118
# Epoch:0169 | train loss:0.3797, val acc:0.8454, time:4.3854, macs:107.5338
# Epoch:0170 | train loss:0.3674, val acc:0.8535, time:4.4010, macs:108.1558
# Epoch:0171 | train loss:0.3894, val acc:0.8535, time:4.4156, macs:108.7778
# Epoch:0172 | train loss:0.3847, val acc:0.8470, time:4.4365, macs:109.3998
# Epoch:0173 | train loss:0.3739, val acc:0.8519, time:4.4516, macs:110.0218
# Epoch:0174 | train loss:0.3593, val acc:0.8502, time:4.4676, macs:110.6438
# Epoch:0175 | train loss:0.3872, val acc:0.8470, time:4.4846, macs:111.2657
# Epoch:0176 | train loss:0.3629, val acc:0.8486, time:4.5015, macs:111.8877
# Epoch:0177 | train loss:0.3834, val acc:0.8486, time:4.5180, macs:112.5097
# Epoch:0178 | train loss:0.3793, val acc:0.8486, time:4.5552, macs:113.1316
# Epoch:0179 | train loss:0.3687, val acc:0.8438, time:4.5719, macs:113.7536
# Epoch:0180 | train loss:0.3711, val acc:0.8470, time:4.5881, macs:114.3755
# Epoch:0181 | train loss:0.3629, val acc:0.8519, time:4.6031, macs:114.9975
# Epoch:0182 | train loss:0.3763, val acc:0.8470, time:4.6219, macs:115.6194
# Epoch:0183 | train loss:0.3884, val acc:0.8454, time:4.6371, macs:116.2413
# Epoch:0184 | train loss:0.3893, val acc:0.8486, time:4.6534, macs:116.8633
# Epoch:0185 | train loss:0.3650, val acc:0.8502, time:4.6702, macs:117.4851
# Epoch:0186 | train loss:0.3737, val acc:0.8470, time:4.6863, macs:118.1071
# Epoch:0187 | train loss:0.3937, val acc:0.8535, time:4.7024, macs:118.7289
# Epoch:0188 | train loss:0.3726, val acc:0.8470, time:4.7187, macs:119.3509
# Epoch:0189 | train loss:0.4010, val acc:0.8502, time:4.7400, macs:119.9729
# Epoch:0190 | train loss:0.3672, val acc:0.8519, time:4.7578, macs:120.5948
# Epoch:0191 | train loss:0.3770, val acc:0.8502, time:4.7758, macs:121.2165
# Epoch:0192 | train loss:0.3772, val acc:0.8438, time:4.7914, macs:121.8385
# Epoch:0193 | train loss:0.3843, val acc:0.8486, time:4.8077, macs:122.4604
# Epoch:0194 | train loss:0.3605, val acc:0.8422, time:4.8236, macs:123.0824
# Epoch:0195 | train loss:0.3695, val acc:0.8502, time:4.8392, macs:123.7043
# Epoch:0196 | train loss:0.3899, val acc:0.8502, time:4.8553, macs:124.3261
# Epoch:0197 | train loss:0.3781, val acc:0.8486, time:4.8700, macs:124.9481
# Epoch:0198 | train loss:0.3741, val acc:0.8519, time:4.8861, macs:125.5700
# Epoch:0199 | train loss:0.3813, val acc:0.8454, time:4.9124, macs:126.1919
# Epoch:0200 | train loss:0.3551, val acc:0.8470, time:4.9286, macs:126.8139
# Epoch:0201 | train loss:0.3632, val acc:0.8519, time:4.9443, macs:127.4359
# Epoch:0202 | train loss:0.3649, val acc:0.8567, time:4.9604, macs:128.0579
# Epoch:0203 | train loss:0.3682, val acc:0.8486, time:4.9768, macs:128.6798
# Epoch:0204 | train loss:0.3623, val acc:0.8454, time:4.9929, macs:129.3018
# Epoch:0205 | train loss:0.3606, val acc:0.8470, time:5.0092, macs:129.9237
# Epoch:0206 | train loss:0.3866, val acc:0.8486, time:5.0254, macs:130.5456
# Epoch:0207 | train loss:0.3477, val acc:0.8519, time:5.0405, macs:131.1676
# Epoch:0208 | train loss:0.3713, val acc:0.8519, time:5.0556, macs:131.7896
# Epoch:0209 | train loss:0.3816, val acc:0.8519, time:5.0711, macs:132.4116
# Epoch:0210 | train loss:0.3842, val acc:0.8519, time:5.0868, macs:133.0336
# Epoch:0211 | train loss:0.3695, val acc:0.8519, time:5.1033, macs:133.6555
# Epoch:0212 | train loss:0.3854, val acc:0.8502, time:5.1191, macs:134.2775
# Epoch:0213 | train loss:0.3692, val acc:0.8486, time:5.1359, macs:134.8994
# Epoch:0214 | train loss:0.3754, val acc:0.8519, time:5.1520, macs:135.5212
# Epoch:0215 | train loss:0.3657, val acc:0.8502, time:5.1683, macs:136.1431
# Epoch:0216 | train loss:0.3855, val acc:0.8486, time:5.1834, macs:136.7651
# Epoch:0217 | train loss:0.3962, val acc:0.8502, time:5.1990, macs:137.3870
# Epoch:0218 | train loss:0.3660, val acc:0.8502, time:5.2160, macs:138.0089
# Epoch:0219 | train loss:0.3607, val acc:0.8535, time:5.2312, macs:138.6309
# Epoch:0220 | train loss:0.3612, val acc:0.8486, time:5.2497, macs:139.2528
# Epoch:0221 | train loss:0.3847, val acc:0.8502, time:5.2765, macs:139.8747
# Epoch:0222 | train loss:0.3835, val acc:0.8502, time:5.2932, macs:140.4966
# Epoch:0223 | train loss:0.3730, val acc:0.8519, time:5.3132, macs:141.1185
# Epoch:0224 | train loss:0.3676, val acc:0.8486, time:5.3294, macs:141.7404
# Epoch:0225 | train loss:0.3837, val acc:0.8486, time:5.3462, macs:142.3623
# Epoch:0226 | train loss:0.3701, val acc:0.8438, time:5.3622, macs:142.9842
# Epoch:0227 | train loss:0.3763, val acc:0.8551, time:5.3776, macs:143.6060
# Epoch:0228 | train loss:0.3846, val acc:0.8502, time:5.3930, macs:144.2280
# Epoch:0229 | train loss:0.3692, val acc:0.8470, time:5.4092, macs:144.8499
# Epoch:0230 | train loss:0.3876, val acc:0.8519, time:5.4256, macs:145.4718
# Epoch:0231 | train loss:0.3505, val acc:0.8551, time:5.4413, macs:146.0937
# Epoch:0232 | train loss:0.3755, val acc:0.8502, time:5.4562, macs:146.7156
# Epoch:0233 | train loss:0.3683, val acc:0.8502, time:5.4726, macs:147.3375
# Epoch:0234 | train loss:0.3731, val acc:0.8502, time:5.4871, macs:147.9595
# Epoch:0235 | train loss:0.3646, val acc:0.8502, time:5.5033, macs:148.5814
# Epoch:0236 | train loss:0.3723, val acc:0.8486, time:5.5186, macs:149.2033
# Epoch:0237 | train loss:0.3873, val acc:0.8519, time:5.5348, macs:149.8252
# Epoch:0238 | train loss:0.3595, val acc:0.8519, time:5.5575, macs:150.4471
# Epoch:0239 | train loss:0.3731, val acc:0.8519, time:5.5880, macs:151.0690
# Epoch:0240 | train loss:0.3759, val acc:0.8502, time:5.6188, macs:151.6908
# Epoch:0241 | train loss:0.3499, val acc:0.8486, time:5.6505, macs:152.3127
# Epoch:0242 | train loss:0.3567, val acc:0.8567, time:5.6734, macs:152.9346
# Epoch:0243 | train loss:0.3927, val acc:0.8519, time:5.7073, macs:153.5566
# Epoch:0244 | train loss:0.3668, val acc:0.8535, time:5.7340, macs:154.1786
# Epoch:0245 | train loss:0.3888, val acc:0.8470, time:5.7697, macs:154.8005
# Epoch:0246 | train loss:0.3692, val acc:0.8486, time:5.8016, macs:155.4222
# Epoch:0247 | train loss:0.3858, val acc:0.8519, time:5.8337, macs:156.0441
# Epoch:0248 | train loss:0.3603, val acc:0.8502, time:5.8724, macs:156.6660
# Epoch:0249 | train loss:0.3770, val acc:0.8535, time:5.9025, macs:157.2879
# Epoch:0250 | train loss:0.3549, val acc:0.8535, time:5.9356, macs:157.9089
# Epoch:0251 | train loss:0.3892, val acc:0.8438, time:5.9641, macs:158.5295
# Epoch:0252 | train loss:0.3621, val acc:0.8535, time:5.9917, macs:159.1498
# Epoch:0253 | train loss:0.3584, val acc:0.8519, time:6.0194, macs:159.7698
# Epoch:0254 | train loss:0.3610, val acc:0.8519, time:6.0621, macs:160.3896
# Epoch:0255 | train loss:0.3774, val acc:0.8438, time:6.0958, macs:161.0093
# Epoch:0256 | train loss:0.3734, val acc:0.8502, time:6.1194, macs:161.6288
# Epoch:0257 | train loss:0.3704, val acc:0.8502, time:6.1515, macs:162.2483
# Epoch:0258 | train loss:0.3555, val acc:0.8486, time:6.1707, macs:162.8677
# Epoch:0259 | train loss:0.3653, val acc:0.8422, time:6.1877, macs:163.4871
# Epoch:0260 | train loss:0.3697, val acc:0.8486, time:6.2038, macs:164.1063
# Epoch:0261 | train loss:0.3572, val acc:0.8502, time:6.2215, macs:164.7255
# Epoch:0262 | train loss:0.3710, val acc:0.8519, time:6.2382, macs:165.3446
# Epoch:0263 | train loss:0.3559, val acc:0.8502, time:6.2707, macs:165.9638
# Epoch:0264 | train loss:0.3640, val acc:0.8486, time:6.3008, macs:166.5828
# Epoch:0265 | train loss:0.3762, val acc:0.8486, time:6.3190, macs:167.2018
# Epoch:0266 | train loss:0.3607, val acc:0.8502, time:6.3492, macs:167.8207
# Epoch:0267 | train loss:0.3553, val acc:0.8470, time:6.3858, macs:168.4396
# Epoch:0268 | train loss:0.3407, val acc:0.8551, time:6.4126, macs:169.0585
# Epoch:0269 | train loss:0.3533, val acc:0.8551, time:6.4397, macs:169.6773
# Epoch:0270 | train loss:0.3748, val acc:0.8486, time:6.4742, macs:170.2961
# Epoch:0271 | train loss:0.3693, val acc:0.8422, time:6.5078, macs:170.9148
# Epoch:0272 | train loss:0.3764, val acc:0.8535, time:6.5211, macs:171.5335
# Epoch:0273 | train loss:0.3888, val acc:0.8519, time:6.5359, macs:172.1520
# Epoch:0274 | train loss:0.3641, val acc:0.8535, time:6.5528, macs:172.7706
# Epoch:0275 | train loss:0.3616, val acc:0.8535, time:6.5795, macs:173.3892
# Epoch:0276 | train loss:0.3956, val acc:0.8454, time:6.6116, macs:174.0077
# Epoch:0277 | train loss:0.3620, val acc:0.8470, time:6.6400, macs:174.6263
# Epoch:0278 | train loss:0.3696, val acc:0.8438, time:6.6710, macs:175.2448
# Epoch:0279 | train loss:0.3695, val acc:0.8486, time:6.7075, macs:175.8632
# Epoch:0280 | train loss:0.3706, val acc:0.8502, time:6.7321, macs:176.4817
# Epoch:0281 | train loss:0.3664, val acc:0.8454, time:6.7681, macs:177.1001
# Epoch:0282 | train loss:0.3675, val acc:0.8535, time:6.7995, macs:177.7184
# Epoch:0283 | train loss:0.3719, val acc:0.8519, time:6.8329, macs:178.3368
# Epoch:0284 | train loss:0.3769, val acc:0.8502, time:6.8711, macs:178.9552
# Epoch:0285 | train loss:0.3795, val acc:0.8486, time:6.9041, macs:179.5736
# Epoch:0286 | train loss:0.3644, val acc:0.8502, time:6.9328, macs:180.1919
# Epoch:0287 | train loss:0.3628, val acc:0.8486, time:6.9673, macs:180.8102
# Epoch:0288 | train loss:0.3756, val acc:0.8486, time:6.9962, macs:181.4285
# Epoch:0289 | train loss:0.3799, val acc:0.8502, time:7.0162, macs:182.0467
# Epoch:0290 | train loss:0.3605, val acc:0.8470, time:7.0362, macs:182.6649
# Epoch:0291 | train loss:0.3573, val acc:0.8486, time:7.0552, macs:183.2831
# Epoch:0292 | train loss:0.3706, val acc:0.8486, time:7.0719, macs:183.9013
# Epoch:0293 | train loss:0.3632, val acc:0.8535, time:7.0886, macs:184.5195
# Epoch:0294 | train loss:0.3697, val acc:0.8454, time:7.1131, macs:185.1377
# Epoch:0295 | train loss:0.3574, val acc:0.8470, time:7.1317, macs:185.7560
# Epoch:0296 | train loss:0.3564, val acc:0.8486, time:7.1487, macs:186.3741
# Epoch:0297 | train loss:0.3673, val acc:0.8519, time:7.1660, macs:186.9922
# Epoch:0298 | train loss:0.3554, val acc:0.8535, time:7.1854, macs:187.6104
# Epoch:0299 | train loss:0.3788, val acc:0.8486, time:7.2023, macs:188.2285
# Epoch:0300 | train loss:0.3632, val acc:0.8454, time:7.2204, macs:188.8466
# Epoch:0301 | train loss:0.3637, val acc:0.8502, time:7.2391, macs:189.4647
# Epoch:0302 | train loss:0.3694, val acc:0.8599, time:7.2600, macs:190.0827
# Epoch:0303 | train loss:0.3745, val acc:0.8502, time:7.2808, macs:190.7008
# Epoch:0304 | train loss:0.3748, val acc:0.8519, time:7.2982, macs:191.3188
# Epoch:0305 | train loss:0.3756, val acc:0.8519, time:7.3153, macs:191.9369
# Epoch:0306 | train loss:0.3676, val acc:0.8502, time:7.3352, macs:192.5549
# Epoch:0307 | train loss:0.3666, val acc:0.8454, time:7.3527, macs:193.1730
# Epoch:0308 | train loss:0.3571, val acc:0.8519, time:7.3692, macs:193.7910
# Epoch:0309 | train loss:0.3753, val acc:0.8438, time:7.3917, macs:194.4090
# Epoch:0310 | train loss:0.3697, val acc:0.8470, time:7.4123, macs:195.0270
# Epoch:0311 | train loss:0.3694, val acc:0.8470, time:7.4349, macs:195.6450
# Epoch:0312 | train loss:0.3693, val acc:0.8519, time:7.4531, macs:196.2630
# Epoch:0313 | train loss:0.3528, val acc:0.8535, time:7.4706, macs:196.8810
# Epoch:0314 | train loss:0.3765, val acc:0.8502, time:7.4888, macs:197.4989
# Epoch:0315 | train loss:0.3850, val acc:0.8502, time:7.5076, macs:198.1169
# Epoch:0316 | train loss:0.3678, val acc:0.8422, time:7.5251, macs:198.7348
# Epoch:0317 | train loss:0.3796, val acc:0.8422, time:7.5427, macs:199.3527
# Epoch:0318 | train loss:0.3539, val acc:0.8470, time:7.5639, macs:199.9706
# Epoch:0319 | train loss:0.3580, val acc:0.8422, time:7.5822, macs:200.5885
# Epoch:0320 | train loss:0.3428, val acc:0.8486, time:7.5996, macs:201.2065
# Epoch:0321 | train loss:0.3646, val acc:0.8535, time:7.6167, macs:201.8244
# Epoch:0322 | train loss:0.3468, val acc:0.8486, time:7.6418, macs:202.4423
# Epoch:0323 | train loss:0.3606, val acc:0.8519, time:7.6600, macs:203.0602
# Epoch:0324 | train loss:0.3613, val acc:0.8454, time:7.6783, macs:203.6780
# Epoch:0325 | train loss:0.3544, val acc:0.8519, time:7.6955, macs:204.2959
# Epoch:0326 | train loss:0.3528, val acc:0.8502, time:7.7146, macs:204.9137
# Epoch:0327 | train loss:0.3585, val acc:0.8519, time:7.7325, macs:205.5316
# Epoch:0328 | train loss:0.3688, val acc:0.8454, time:7.7489, macs:206.1494
# Epoch:0329 | train loss:0.3751, val acc:0.8486, time:7.7703, macs:206.7673
# Epoch:0330 | train loss:0.3459, val acc:0.8519, time:7.7902, macs:207.3851
# Epoch:0331 | train loss:0.3406, val acc:0.8486, time:7.8067, macs:208.0029
# Epoch:0332 | train loss:0.3654, val acc:0.8438, time:7.8251, macs:208.6207
# Epoch:0333 | train loss:0.3668, val acc:0.8422, time:7.8431, macs:209.2385
# Epoch:0334 | train loss:0.3736, val acc:0.8470, time:7.8605, macs:209.8563
# Epoch:0335 | train loss:0.3519, val acc:0.8454, time:7.8772, macs:210.4741
# Epoch:0336 | train loss:0.3558, val acc:0.8519, time:7.8935, macs:211.0918
# Epoch:0337 | train loss:0.3674, val acc:0.8551, time:7.9101, macs:211.7095
# Epoch:0338 | train loss:0.3719, val acc:0.8519, time:7.9264, macs:212.3272
# Epoch:0339 | train loss:0.3868, val acc:0.8519, time:7.9434, macs:212.9449
# Epoch:0340 | train loss:0.3821, val acc:0.8454, time:7.9608, macs:213.5626
# Epoch:0341 | train loss:0.3848, val acc:0.8470, time:7.9808, macs:214.1803
# Epoch:0342 | train loss:0.3698, val acc:0.8470, time:7.9999, macs:214.7979
# Epoch:0343 | train loss:0.3586, val acc:0.8486, time:8.0185, macs:215.4156
# Epoch:0344 | train loss:0.3681, val acc:0.8486, time:8.0341, macs:216.0333
# Epoch:0345 | train loss:0.3841, val acc:0.8422, time:8.0495, macs:216.6509
# Epoch:0346 | train loss:0.3501, val acc:0.8502, time:8.0677, macs:217.2685
# Epoch:0347 | train loss:0.3485, val acc:0.8486, time:8.0844, macs:217.8861
# Epoch:0348 | train loss:0.3689, val acc:0.8519, time:8.1004, macs:218.5037
# Epoch:0349 | train loss:0.3472, val acc:0.8438, time:8.1200, macs:219.1212
# Epoch:0350 | train loss:0.3480, val acc:0.8438, time:8.1391, macs:219.7388
# Epoch:0351 | train loss:0.3578, val acc:0.8519, time:8.1567, macs:220.3563
# Epoch:0352 | train loss:0.3622, val acc:0.8454, time:8.1740, macs:220.9738
# Epoch:0353 | train loss:0.3750, val acc:0.8454, time:8.1910, macs:221.5914
# Epoch:0354 | train loss:0.3746, val acc:0.8454, time:8.2089, macs:222.2089
# Epoch:0355 | train loss:0.3762, val acc:0.8502, time:8.2261, macs:222.8264
# Epoch:0356 | train loss:0.3841, val acc:0.8438, time:8.2437, macs:223.4439
# Epoch:0357 | train loss:0.3735, val acc:0.8535, time:8.2615, macs:224.0614
# Epoch:0358 | train loss:0.3635, val acc:0.8470, time:8.2791, macs:224.6789
# Epoch:0359 | train loss:0.3704, val acc:0.8502, time:8.2963, macs:225.2964
# Epoch:0360 | train loss:0.3643, val acc:0.8535, time:8.3124, macs:225.9139
# Epoch:0361 | train loss:0.3730, val acc:0.8535, time:8.3322, macs:226.5314
# Epoch:0362 | train loss:0.3579, val acc:0.8502, time:8.3491, macs:227.1489
# Epoch:0363 | train loss:0.3900, val acc:0.8519, time:8.3654, macs:227.7664
# Epoch:0364 | train loss:0.3592, val acc:0.8422, time:8.3826, macs:228.3838
# Epoch:0365 | train loss:0.3665, val acc:0.8470, time:8.4001, macs:229.0013
# Epoch:0366 | train loss:0.3612, val acc:0.8486, time:8.4183, macs:229.6188
# Epoch:0367 | train loss:0.3809, val acc:0.8535, time:8.4350, macs:230.2363
# Epoch:0368 | train loss:0.3628, val acc:0.8486, time:8.4509, macs:230.8537
# Epoch:0369 | train loss:0.3847, val acc:0.8470, time:8.4713, macs:231.4712
# Epoch:0370 | train loss:0.3766, val acc:0.8519, time:8.4883, macs:232.0886
# Epoch:0371 | train loss:0.3669, val acc:0.8486, time:8.5055, macs:232.7061
# Epoch:0372 | train loss:0.3676, val acc:0.8519, time:8.5238, macs:233.3235
# Epoch:0373 | train loss:0.3810, val acc:0.8454, time:8.5408, macs:233.9410
# Epoch:0374 | train loss:0.3736, val acc:0.8422, time:8.5782, macs:234.5585
# Epoch:0375 | train loss:0.3751, val acc:0.8486, time:8.5959, macs:235.1759
# Epoch:0376 | train loss:0.3485, val acc:0.8502, time:8.6122, macs:235.7934
# Epoch:0377 | train loss:0.3588, val acc:0.8519, time:8.6299, macs:236.4109
# Epoch:0378 | train loss:0.3634, val acc:0.8486, time:8.6486, macs:237.0283
# Epoch:0379 | train loss:0.3707, val acc:0.8454, time:8.6664, macs:237.6457
# Epoch:0380 | train loss:0.3628, val acc:0.8502, time:8.6993, macs:238.2632
# Epoch:0381 | train loss:0.3631, val acc:0.8486, time:8.7183, macs:238.8806
# Epoch:0382 | train loss:0.3596, val acc:0.8486, time:8.7386, macs:239.4980
# Epoch:0383 | train loss:0.3817, val acc:0.8486, time:8.7589, macs:240.1154
# Epoch:0384 | train loss:0.3789, val acc:0.8438, time:8.7760, macs:240.7328
# Epoch:0385 | train loss:0.3700, val acc:0.8502, time:8.7929, macs:241.3503
# Epoch:0386 | train loss:0.3776, val acc:0.8519, time:8.8108, macs:241.9677
# Epoch:0387 | train loss:0.3637, val acc:0.8502, time:8.8281, macs:242.5851
# Epoch:0388 | train loss:0.3716, val acc:0.8535, time:8.8474, macs:243.2025
# Epoch:0389 | train loss:0.3769, val acc:0.8502, time:8.8655, macs:243.8199
# Epoch:0390 | train loss:0.3584, val acc:0.8519, time:8.8839, macs:244.4373
# Epoch:0391 | train loss:0.3747, val acc:0.8486, time:8.9052, macs:245.0547
# Epoch:0392 | train loss:0.3549, val acc:0.8470, time:8.9215, macs:245.6721
# Epoch:0393 | train loss:0.3681, val acc:0.8486, time:8.9409, macs:246.2894
# Epoch:0394 | train loss:0.3724, val acc:0.8551, time:8.9591, macs:246.9068
# Epoch:0395 | train loss:0.3676, val acc:0.8502, time:8.9759, macs:247.5242
# Epoch:0396 | train loss:0.3672, val acc:0.8486, time:8.9926, macs:248.1416
# Epoch:0397 | train loss:0.3523, val acc:0.8535, time:9.0102, macs:248.7589
# Epoch:0398 | train loss:0.3763, val acc:0.8438, time:9.0291, macs:249.3762
# Epoch:0399 | train loss:0.3509, val acc:0.8438, time:9.0490, macs:249.9936
# Epoch:0400 | train loss:0.3668, val acc:0.8470, time:9.0672, macs:250.6109
# Epoch:0401 | train loss:0.3662, val acc:0.8470, time:9.0840, macs:251.2282
# Epoch:0402 | train loss:0.3575, val acc:0.8502, time:9.1013, macs:251.8456
# Epoch:0403 | train loss:0.3702, val acc:0.8470, time:9.1196, macs:252.4629
# Epoch:0404 | train loss:0.3552, val acc:0.8535, time:9.1363, macs:253.0802
# Epoch:0405 | train loss:0.3559, val acc:0.8535, time:9.1538, macs:253.6976
# Epoch:0406 | train loss:0.3567, val acc:0.8535, time:9.1722, macs:254.3149
# Epoch:0407 | train loss:0.3619, val acc:0.8502, time:9.1890, macs:254.9322
# Epoch:0408 | train loss:0.3607, val acc:0.8486, time:9.2080, macs:255.5495
# Epoch:0409 | train loss:0.3698, val acc:0.8486, time:9.2239, macs:256.1668
# Epoch:0410 | train loss:0.3768, val acc:0.8502, time:9.2401, macs:256.7841
# Epoch:0411 | train loss:0.3511, val acc:0.8519, time:9.2567, macs:257.4014
# Epoch:0412 | train loss:0.3518, val acc:0.8502, time:9.2807, macs:258.0187
# Epoch:0413 | train loss:0.3550, val acc:0.8519, time:9.2962, macs:258.6359
# Epoch:0414 | train loss:0.3504, val acc:0.8454, time:9.3135, macs:259.2532
# Epoch:0415 | train loss:0.3564, val acc:0.8470, time:9.3512, macs:259.8705
# Epoch:0416 | train loss:0.3701, val acc:0.8454, time:9.3675, macs:260.4877
# Epoch:0417 | train loss:0.3591, val acc:0.8438, time:9.3839, macs:261.1050
# Epoch:0418 | train loss:0.3848, val acc:0.8519, time:9.4018, macs:261.7223
# Epoch:0419 | train loss:0.3639, val acc:0.8519, time:9.4193, macs:262.3395
# Epoch:0420 | train loss:0.3629, val acc:0.8519, time:9.4366, macs:262.9567
# Epoch:0421 | train loss:0.3490, val acc:0.8470, time:9.4540, macs:263.5740
# Epoch:0422 | train loss:0.3702, val acc:0.8551, time:9.4722, macs:264.1912
# Epoch:0423 | train loss:0.3758, val acc:0.8519, time:9.4899, macs:264.8084
# Epoch:0424 | train loss:0.3619, val acc:0.8470, time:9.5059, macs:265.4257
# Epoch:0425 | train loss:0.3715, val acc:0.8454, time:9.5217, macs:266.0429
# Epoch:0426 | train loss:0.3734, val acc:0.8502, time:9.5393, macs:266.6601
# Epoch:0427 | train loss:0.3737, val acc:0.8470, time:9.5557, macs:267.2773
# Epoch:0428 | train loss:0.3825, val acc:0.8486, time:9.5732, macs:267.8945
# Epoch:0429 | train loss:0.3516, val acc:0.8551, time:9.5906, macs:268.5117
# Epoch:0430 | train loss:0.3656, val acc:0.8519, time:9.6096, macs:269.1289
# Epoch:0431 | train loss:0.3594, val acc:0.8502, time:9.6280, macs:269.7461
# Epoch:0432 | train loss:0.3589, val acc:0.8519, time:9.6452, macs:270.3632
# Epoch:0433 | train loss:0.3678, val acc:0.8502, time:9.6638, macs:270.9804
# Epoch:0434 | train loss:0.3765, val acc:0.8519, time:9.6826, macs:271.5975
# Epoch:0435 | train loss:0.3810, val acc:0.8486, time:9.7006, macs:272.2147
# Epoch:0436 | train loss:0.3851, val acc:0.8502, time:9.7294, macs:272.8319
# Epoch:0437 | train loss:0.3796, val acc:0.8438, time:9.7467, macs:273.4490
# Epoch:0438 | train loss:0.3628, val acc:0.8535, time:9.7659, macs:274.0661
# Epoch:0439 | train loss:0.3648, val acc:0.8486, time:9.7868, macs:274.6833
# Epoch:0440 | train loss:0.3375, val acc:0.8519, time:9.8032, macs:275.3004
# Epoch:0441 | train loss:0.3654, val acc:0.8567, time:9.8192, macs:275.9175
# Epoch:0442 | train loss:0.3687, val acc:0.8438, time:9.8371, macs:276.5347
# Epoch:0443 | train loss:0.3726, val acc:0.8486, time:9.8545, macs:277.1518
# Epoch:0444 | train loss:0.3640, val acc:0.8438, time:9.8719, macs:277.7689
# Epoch:0445 | train loss:0.3475, val acc:0.8519, time:9.8900, macs:278.3861
# Epoch:0446 | train loss:0.3570, val acc:0.8535, time:9.9082, macs:279.0032
# Epoch:0447 | train loss:0.3802, val acc:0.8454, time:9.9259, macs:279.6203
# Epoch:0448 | train loss:0.3683, val acc:0.8502, time:9.9406, macs:280.2374
# Epoch:0449 | train loss:0.3570, val acc:0.8535, time:9.9559, macs:280.8545
# Epoch:0450 | train loss:0.3775, val acc:0.8486, time:9.9742, macs:281.4716
# Epoch:0451 | train loss:0.3668, val acc:0.8486, time:9.9908, macs:282.0887
# Epoch:0452 | train loss:0.3787, val acc:0.8454, time:10.0075, macs:282.7057
# Epoch:0453 | train loss:0.3527, val acc:0.8486, time:10.0248, macs:283.3228
# Epoch:0454 | train loss:0.3611, val acc:0.8454, time:10.0430, macs:283.9399
# Epoch:0455 | train loss:0.3632, val acc:0.8486, time:10.0598, macs:284.5570
# Epoch:0456 | train loss:0.3611, val acc:0.8519, time:10.0755, macs:285.1741
# Epoch:0457 | train loss:0.3765, val acc:0.8454, time:10.0980, macs:285.7912
# Epoch:0458 | train loss:0.3834, val acc:0.8470, time:10.1159, macs:286.4083
# Epoch:0459 | train loss:0.3466, val acc:0.8519, time:10.1332, macs:287.0254
# Epoch:0460 | train loss:0.3686, val acc:0.8502, time:10.1497, macs:287.6425
# Epoch:0461 | train loss:0.3650, val acc:0.8454, time:10.1673, macs:288.2596
# Epoch:0462 | train loss:0.3507, val acc:0.8535, time:10.1861, macs:288.8766
# Epoch:0463 | train loss:0.3886, val acc:0.8486, time:10.2045, macs:289.4937
# Epoch:0464 | train loss:0.3714, val acc:0.8470, time:10.2199, macs:290.1108
# Epoch:0465 | train loss:0.3736, val acc:0.8486, time:10.2365, macs:290.7278
# Epoch:0466 | train loss:0.3659, val acc:0.8502, time:10.2536, macs:291.3449
# Epoch:0467 | train loss:0.3566, val acc:0.8486, time:10.2701, macs:291.9620
# Epoch:0468 | train loss:0.3573, val acc:0.8486, time:10.2867, macs:292.5790
# Epoch:0469 | train loss:0.3695, val acc:0.8486, time:10.3027, macs:293.1961
# Epoch:0470 | train loss:0.3697, val acc:0.8422, time:10.3209, macs:293.8131
# Epoch:0471 | train loss:0.3735, val acc:0.8519, time:10.3418, macs:294.4302
# Epoch:0472 | train loss:0.3620, val acc:0.8486, time:10.3582, macs:295.0472
# Epoch:0473 | train loss:0.3619, val acc:0.8438, time:10.3748, macs:295.6643
# Epoch:0474 | train loss:0.3625, val acc:0.8422, time:10.3926, macs:296.2813
# Epoch:0475 | train loss:0.3662, val acc:0.8454, time:10.4101, macs:296.8984
# Epoch:0476 | train loss:0.3667, val acc:0.8519, time:10.4279, macs:297.5154
# Epoch:0477 | train loss:0.3534, val acc:0.8454, time:10.4461, macs:298.1324
# Epoch:0478 | train loss:0.3718, val acc:0.8486, time:10.4662, macs:298.7494
# Epoch:0479 | train loss:0.3618, val acc:0.8535, time:10.4839, macs:299.3665
# Epoch:0480 | train loss:0.3667, val acc:0.8502, time:10.5047, macs:299.9834
# Epoch:0481 | train loss:0.3664, val acc:0.8502, time:10.5217, macs:300.6005
# Epoch:0482 | train loss:0.3746, val acc:0.8454, time:10.5422, macs:301.2175
# Epoch:0483 | train loss:0.3740, val acc:0.8502, time:10.5608, macs:301.8345
# Epoch:0484 | train loss:0.3438, val acc:0.8454, time:10.5791, macs:302.4515
# Epoch:0485 | train loss:0.3602, val acc:0.8454, time:10.6044, macs:303.0686
# Epoch:0486 | train loss:0.3840, val acc:0.8438, time:10.6314, macs:303.6856
# Epoch:0487 | train loss:0.3792, val acc:0.8551, time:10.6516, macs:304.3026
# Epoch:0488 | train loss:0.3728, val acc:0.8551, time:10.6700, macs:304.9196
# Epoch:0489 | train loss:0.3755, val acc:0.8486, time:10.6988, macs:305.5366
# Epoch:0490 | train loss:0.3619, val acc:0.8502, time:10.7369, macs:306.1536
# Epoch:0491 | train loss:0.3605, val acc:0.8470, time:10.7599, macs:306.7706
# Epoch:0492 | train loss:0.3654, val acc:0.8470, time:10.7888, macs:307.3876
# Epoch:0493 | train loss:0.3882, val acc:0.8486, time:10.8191, macs:308.0046
# Epoch:0494 | train loss:0.3600, val acc:0.8535, time:10.8549, macs:308.6216
# Epoch:0495 | train loss:0.3562, val acc:0.8502, time:10.8842, macs:309.2386
# Epoch:0496 | train loss:0.3931, val acc:0.8567, time:10.9197, macs:309.8556
# Epoch:0497 | train loss:0.3749, val acc:0.8535, time:10.9414, macs:310.4725
# Epoch:0498 | train loss:0.3489, val acc:0.8502, time:10.9810, macs:311.0894
# Epoch:0499 | train loss:0.3552, val acc:0.8535, time:11.0099, macs:311.7064
# Epoch:0500 | train loss:0.3704, val acc:0.8454, time:11.0367, macs:312.3234
# [Val] best acc: 0.85990 (epoch: 33/500), [Test] best acc: 0.86656
# [Train] time: 11.0367 s (avg: 22.1 ms), MACs: 312.323 G (avg: 0.6 G)
# [Test]  time: 0.0168 s, MACs: 0.6495 G, Num adj: 27.439 k, Num weight: 253.527 k
#       Data|     Model|  Seed|     ThA|     ThW|    Acc|  Cn|  EP|  Ttrain|  Ctrain|   Ttest|   CTest|  NumelA|  NumelW
# cora      ,gcn_thr   ,    42,5.00e-01,5.00e-01,0.86656,  33, 500, 11.0367, 312.323,  0.0168,  0.6495,  27.439, 253.527
# ^C

# %%
# !python run_fb.py -f 42 -c config/cora_mb.json -v 0
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pydantic/main.py", line 949, in __class_getitem__
#     submodel = _generics.create_generic_submodel(model_name, origin, args, params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generics.py", line 127, in create_generic_submodel
#     created_model = meta(
#                     ^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pydantic/_internal/_model_construction.py", line 242, in __new__
#     set_model_fields(cls, config_wrapper=config_wrapper, ns_resolver=ns_resolver)
#   File "/usr/local/lib/python3.12/dist-packages/pydantic/_internal/_model_construction.py", line 566, in set_model_fields
#     fields, class_vars = collect_model_fields(cls, config_wrapper, ns_resolver, typevars_map=typevars_map)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pydantic/_internal/_fields.py", line 411, in collect_model_fields
# ^C

# %% [markdown]
# ## Computer

# %%
# !python run_fb.py -f 42 -c config/computers.json -v 0
# Out:
# ^C

# %%
# !python run_fb.py -f 42 -c config/computers_lp.json -v 0
# Out:
# ^C

# %%
from torch_geometric.nn import SGConv
layer_dict['sgc'] = SGConv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_34058/2532561180.py in <cell line: 0>()
#       1 from torch_geometric.nn import SGConv
# ----> 2 layer_dict['sgc'] = SGConv
#
# NameError: name 'layer_dict' is not defined

# %% [markdown]
# -f --seed
# -v --dev
# -c --config
# -m --algo
# -n --suffix
# -a --thr_a
# -w --thr_w
# -l --layer

# %%
# !python run_fb.py -f 42 -c config/computers_mb.json -v 0
