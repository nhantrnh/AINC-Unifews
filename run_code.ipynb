# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/MyDrive/Master/AINC/Project/Unifews")
# Move to the directory Unifews
# Out:
# Mounted at /content/drive

# %%
# !pip install torch_geometric ogb eigency ptflops dotmap powerlaw  -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.0/192.0 kB 11.1 MB/s eta 0:00:00

# %%
# !python run_fb.py

# %% [markdown]
# -f --seed
# -v --dev
# -c --config
# -m --algo
# -n --suffix
# -a --thr_a
# -w --thr_w
# -l --layer

# %%
# !python run_fb.py -f 42 -c config/cs.json -v 0
# Out:
# Option saved.
# Config path: ./save/cs/gcn_thr/42-5.0e-01-5.0e-01/config.json
# Option dict: {'data': 'cs', 'path': './data/', 'algo': 'gcn_thr', 'epochs': 200, 'patience': 20, 'lr': 0.001, 'weight_decay': 1e-05, 'layer': 2, 'hidden': 512, 'dropout': 0.5, 'thr_a': 0.5, 'thr_w': 0.5, 'inductive': False, 'multil': False, 'seed': 42, 'dev': 0, 'config': 'config/cs.json', 'suffix': ''}
#
# n=18333, m=163788, F=6805, C=15 | feat: (18333, 6805), label: (18333,) | 9166/4583/4584=0.50/0.25/0.25
# GNNThr gcn_thr 0.5 0.5
# GNNThr(
#   (dropout): Dropout(p=0.5, inplace=False)
#   (act): ReLU()
#   (convs): ModuleList(
#     (0): GCNConvThr(6805, 512)
#     (1): GCNConvThr(512, 15)
#   )
#   (norms): ModuleList(
#     (0): BatchNorm1d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   )
# )
# Epoch:0001 | train loss:3.1477, val acc:0.7225, time:1.3069, macs:40.4899
# Epoch:0002 | train loss:1.0850, val acc:0.8394, time:1.3597, macs:79.8689
# ...

# %%
# %%bash
# ALGO=gcn_thr
# THRA=0.5e+00
# SEED=42
#
# for DATASTR in cora cs computers
# do
#     for THRW in 0.0e+00 2.0e-01 4.0e-01 8.0e-01 1.0e+00 1.2e+00 1.4e+00 1.6e+00 1.8e+00 2.0e+00 2.5e+00 3.0e+00
#     do
#         OUTDIR=./save_w1/${DATASTR}/${ALGO}/${SEED}-${THRA}-${THRW}
#         mkdir -p ${OUTDIR}
#         OUTFILE=${OUTDIR}/out.txt
#
#         python -u run_fb.py --seed ${SEED} --config ./config/${DATASTR}.json --dev 0 \
#             --algo ${ALGO} --thr_a ${THRA} --thr_w ${THRW}
#     done
# done
# Out:
# Option saved.
# Config path: ./save/cora/gcn_thr/42-5.0e-01-0.0e+00/config.json
# Option dict: {'data': 'cora', 'path': './data/', 'algo': 'gcn_thr', 'epochs': 200, 'patience': 20, 'lr': 0.001, 'weight_decay': 1e-05, 'layer': 2, 'hidden': 512, 'dropout': 0.5, 'thr_a': 0.5, 'thr_w': 0.0, 'inductive': False, 'multil': False, 'seed': 42, 'dev': 0, 'config': './config/cora.json', 'suffix': ''}
#
# n=2485, m=12623, F=1433, C=7 | feat: (2485, 1433), label: (2485,) | 1242/621/622=0.50/0.25/0.25
# GNNThr gcn_thr 0.5 0.0
# GNNThr(
#   (dropout): Dropout(p=0.5, inplace=False)
#   (act): ReLU()
#   (convs): ModuleList(
#     (0): GCNConvThr(1433, 512)
#     (1): GCNConvThr(512, 7)
#   )
#   (norms): ModuleList(
#     (0): BatchNorm1d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   )
# )
# Epoch:0001 | train loss:2.0177, val acc:0.6329, time:0.4469, macs:1.8518
# Epoch:0002 | train loss:1.3452, val acc:0.7810, time:0.4569, macs:3.7035
# ...
