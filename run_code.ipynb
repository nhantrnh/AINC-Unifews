# %%
from google.colab import drive
drive.mount('/content/drive/MyDrive/Project')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3940520039.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive/MyDrive/Project')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     198     normed = _os.path.normpath(mountpoint)
#     199     if '/' in normed and not _os.path.exists(_os.path.dirname(normed)):
# ...

# %% [markdown]
# This code will mount your Google Drive to the `/content/drive` directory in your Colab environment. You will be prompted to authorize access to your Google Drive.

# %%
import os

os.chdir("/content/drive/MyDrive/Master/AINC")

# %%
# !pip install -q gdown
# !gdown --folder https://drive.google.com/drive/folders/1_5kJLcXJuln6Z3yserbXXe9tK4T6UFOZ
# Out:
# Retrieving folder contents
# Retrieving folder 13rtZcfSGAB_-FEZYjbffWbT_CjQs59oj Unifews
# Retrieving folder 1vqOusljpvKhg3yY_UzsCStb4OJC1xcM- .git
# Retrieving folder 1SftFsSyePcRs3BMPvB2hBXLCtBnwXD89 branches
# Retrieving folder 14BBDQCf5LCs-Ft35H-nFYLnOjwI88oYu hooks
# Processing file 1w2KkHaPyYyN5nyLljnFr6T6IDyYrxSyt applypatch-msg.sample
# Processing file 1OL8byNpv-GYvE-VS21ecpqAgzxhg1Fpg commit-msg.sample
# Processing file 1oYWAPxS8F9KESaHyLNHjXq6SDpR0Lq97 fsmonitor-watchman.sample
# Processing file 1xGptQgHbyQYNvHYIbNYvP8tYhaqpMTfA post-update.sample
# Processing file 11I0VNBblYkZSPhh2khwSLXKqmez3m_qf pre-applypatch.sample
# Processing file 1gZyFTSMV84wuInLv8vx0_4zXCtZEP7-u pre-commit.sample
# Processing file 1JfQpxalcICm0l3xrWTOIKYfkoSNPZ89a pre-merge-commit.sample
# Processing file 1Cy3i7CrEWMOQ-KEhn4HvvuMlRJOx4mc8 pre-push.sample
# Processing file 1NXI-1h057jU5CsaLm-p7Y79LEDG7eH1r pre-rebase.sample
# Processing file 1s1WILjK8a9VTrCWxXQFkQvHDgMrWToMD pre-receive.sample
# ...

# %%
# !ls
# Out:
# '1_5kJLcXJuln6Z3yserbXXe9tK4T6UFOZ?fbclid=IwY2xjawPiZONleHRuA2FlbQIxMABicmlkETFndElaUjRIbHVaeTV0dG50c3J0YwZhcHBfaWQQMjIyMDM5MTc4ODIwMDg5MgABHt1W4mdqDEU_mro9k2WMZvuOD-VmNk890ksbxnXrGp4j3x3ZoBXOh-hv5b6M_aem_apnrIrqDRopoiODaS7NLww'
#  drive
#  sample_data

# %%
# !git clone https://github.com/gdmnl/Unifews.git
# %cd /content/drive/MyDrive/Master/AINC
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Master/AINC'
# /

# %%
# !ls
# Out:
# '1_5kJLcXJuln6Z3yserbXXe9tK4T6UFOZ?fbclid=IwY2xjawPiZONleHRuA2FlbQIxMABicmlkETFndElaUjRIbHVaeTV0dG50c3J0YwZhcHBfaWQQMjIyMDM5MTc4ODIwMDg5MgABHt1W4mdqDEU_mro9k2WMZvuOD-VmNk890ksbxnXrGp4j3x3ZoBXOh-hv5b6M_aem_apnrIrqDRopoiODaS7NLww'
#  drive
#  sample_data

# %%
# !pip install torch_geometric ogb eigency ptflops dotmap powerlaw  -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.0/192.0 kB 21.3 MB/s eta 0:00:00
# ...

# %%
# !sudo apt install libeigen3-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   libeigen3-doc libmpfrc++-dev
# The following NEW packages will be installed:
#   libeigen3-dev
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,056 kB of archives.
# After this operation, 9,081 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeigen3-dev all 3.4.0-2ubuntu2 [1,056 kB]
# Fetched 1,056 kB in 1s (783 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# ...

# %%
# !python utils/data_transfer.py

# %%
# !ls
# Out:
# '1_5kJLcXJuln6Z3yserbXXe9tK4T6UFOZ?fbclid=IwY2xjawPiZONleHRuA2FlbQIxMABicmlkETFndElaUjRIbHVaeTV0dG50c3J0YwZhcHBfaWQQMjIyMDM5MTc4ODIwMDg5MgABHt1W4mdqDEU_mro9k2WMZvuOD-VmNk890ksbxnXrGp4j3x3ZoBXOh-hv5b6M_aem_apnrIrqDRopoiODaS7NLww'
#  drive
#  sample_data

# %%
# %cd utils
# Out:
# [Errno 2] No such file or directory: 'utils'
# /

# %%
# !python ./setup.py build_ext --inplace
# Out:
# python3: can't open file '/content/./setup.py': [Errno 2] No such file or directory

# %%
# %cd ..
# Out:
# /

# %%
# !python run_fb.py
# Out:
# python3: can't open file '//run_fb.py': [Errno 2] No such file or directory

# %%
# !python run_mb.py
# Out:
# python3: can't open file '//run_mb.py': [Errno 2] No such file or directory
